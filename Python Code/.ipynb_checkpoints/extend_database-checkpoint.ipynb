# %% [markdown]
# # Pronosoft Football Data - Extend Database

# %% [markdown]
# Extend original Database with additional columns & features:
# - Expected Value (EV)
# - Match Outcome (1, N or 2)
# - Pronosoft Prediction Outcome (0 or 1)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Import Lib

# %%
import sys
import os
from os import path
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv

import datetime as dt

# %% [markdown]
# ---

# %% [markdown]
# # Paths

# %%
folder_data = '..\Data'
csv_name = folder_data + '\pronosoft_data.csv'
csv_name_extended = folder_data + '\pronosoft_data_extended.csv'

# %% [markdown]
# ---

# %% [markdown]
# # Functions

# %% [markdown]
# Find Insert Column Location

# %%
def find_insert_loc(col_next_to):
    col_next_loc = list(df_pronosoft_data.columns).index(col_next_to)
    return col_next_loc + 1

# %% [markdown]
# Compute Expected Value (EV)

# %%
def get_col_ev(col_prob, col_odd):    
    col_ev = col_prob * (col_odd.astype(float) - 1) - (1 - col_prob)
    return np.round(col_ev, 2)

# %% [markdown]
# Get Pronosoft Prediction Outcome

# %%
def get_col_prediction_team_outcome(col_bet, col_match_outcome):
    col_bet_outcome = []
    
    for idx in range(len(col_bet)):
        if not pd.isna(col_bet[idx]) and col_match_outcome[idx] in col_bet[idx]:
            col_bet_outcome.append(1)
        elif not pd.isna(col_bet[idx]) and col_match_outcome[idx] not in col_bet[idx]:
            col_bet_outcome.append(0)
        else:
            col_bet_outcome.append(None)
    
    return col_bet_outcome

# %%
def get_col_prediction_uo_outcome(col_bet, col_score_team_1, col_score_team_2):
    col_bet_outcome = []
    
    for idx in range(len(col_bet)):
        if pd.isna(col_bet[idx]):
            col_bet_outcome.append(None)
        else:
            if (col_score_team_1[idx] + col_score_team_2[idx]) < 2.5 and col_bet[idx] == 'U':
                col_bet_outcome.append(1)
            elif (col_score_team_1[idx] + col_score_team_2[idx]) > 2.5 and col_bet[idx] == 'O':
                col_bet_outcome.append(1)
            else:
                col_bet_outcome.append(0)
    
    return col_bet_outcome

# %% [markdown]
# Get Match Outcome

# %%
def get_col_match_outcome(col_score_team_1, col_score_team_2):
    col_match_outcome = []
    
    for idx in range(len(col_score_team_1)):
        if col_score_team_1[idx] > col_score_team_2[idx]:
            col_match_outcome.append('1')
        elif col_score_team_1[idx] < col_score_team_2[idx]:
            col_match_outcome.append('2')
        else:
            col_match_outcome.append('N')
            
    return col_match_outcome

# %% [markdown]
# Get Probabilities of outcome from Betting Odds

# %%
def get_col_prob_from_odds(col_target_outcome, col_other_outcome_1, col_other_outcome_2):    
    
    col_prob_from_odds = 1 / (col_target_outcome * ((1/col_target_outcome) + (1/col_other_outcome_1) + (1/col_other_outcome_2)))
    
    return np.round(col_prob_from_odds, 2)

# %% [markdown]
# Modify Field Names

# %%
def mod_field_names(new_field_names):
    df = pd.read_csv(csv_name)
    cols = df.columns

    new_names = {cols[i]: new_field_names[i] for i in range(len(new_field_names))}

    df_mod = df_pronosoft_data.rename(columns = new_names)
    df_mod.to_csv(csv_name, index = False)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Import CSV to Dataframe

# %%
df_pronosoft_data = pd.read_csv(csv_name)
df_pronosoft_data.head()
# Out:
#          date                       league   time  team_1_name  \
# 0  01-10-2018             France - Ligue 2  20:45       Troyes
# 1  01-10-2018     Espagne - Liga Espagnole  21:00   Celta Vigo
# 2  01-10-2018  Angleterre - Premier League  21:00  Bournemouth
# 3  01-10-2018             Italie - Serie A  20:30    Sampdoria
# 4  01-10-2018     Portugal - Primeira Liga  21:15         Aves
#
#       team_2_name  team_1_prob  team_1_bet_odds  nul_prob  nul_bet_odds  \
# 0         Auxerre         0.39             2.75      0.18          3.10
# 1          Getafe         0.33             2.15      0.38          3.20
# 2  Crystal Palace         0.39             2.20      0.25          3.40
# 3            Spal         0.41             1.72      0.25          3.50
# 4    Portimonense         0.40             2.60      0.30          3.25
#
#    team_2_prob  team_2_bet_odds prediction_team_pronosoft  under_prob  \
# 0         0.43             2.80                       NaN        0.68
# 1         0.30             3.60                         N        0.51
# 2         0.36             3.20                       NaN        0.40
# 3         0.33             4.80                       NaN        0.57
# 4         0.30             2.45                       NaN        0.69
#
#    under_bet_odds  over_prob  over_bet_odds prediction_uo_pronosoft  \
# 0            1.46       0.32           2.00                       U
# 1            1.53       0.49           1.88                     NaN
# 2            1.85       0.60           1.65                       O
# 3            1.67       0.43           1.85                     NaN
# 4            1.66       0.31           1.73                       U
#
#    team_1_score  team_2_score
# 0             1             0
# 1             1             1
# 2             2             1
# 3             2             1
# 4             3             0

# %% [markdown]
# Modify Field Names

# %%
# new_field_names = [ 
#     "date",
#     "league",
#     "time",
#     "team_1_name",
#     "team_2_name",
#     "team_1_prob",
#     "team_1_bet_odds",
#     "nul_prob",
#     "nul_bet_odds",
#     "team_2_prob",
#     "team_2_bet_odds",
#     "prediction_team_pronosoft",
#     "under_prob",
#     "under_bet_odds",
#     "over_prob",
#     "over_bet_odds",
#     "prediction_uo_pronosoft",
#     "team_1_score",
#     "team_2_score"
# ]

# csv_to_mod = csv_name

# mod_field_names(csv_to_mod, new_field_names)

# %% [markdown]
# ---

# %% [markdown]
# # Add Features

# %% [markdown]
# Add EV

# %%
cols_ev = {
    'team_1_ev': find_insert_loc('team_1_bet_odds'), 
    'nul_ev': find_insert_loc('nul_bet_odds'),
    'team_2_ev': find_insert_loc('team_2_bet_odds'),
    'under_ev': find_insert_loc('under_bet_odds'),
    'over_ev': find_insert_loc('over_bet_odds')
}

counter = 0
for key, value in cols_ev.items():    
    col_ev = get_col_ev(df_pronosoft_data[key[:-2] + 'prob'], df_pronosoft_data[key[:-2] + 'bet_odds'])
    df_pronosoft_data.insert(loc = value + counter, column = key, value = col_ev, allow_duplicates = True)
    
    counter += 1

# %% [markdown]
# Add Match Outcome

# %%
col_new = 'match_outcome'
col_next_to = 'team_2_score'

col_match_outcome = get_col_match_outcome(df_pronosoft_data['team_1_score'], df_pronosoft_data['team_2_score'])
df_pronosoft_data.insert(loc = find_insert_loc(col_next_to), column = col_new, value = col_match_outcome, allow_duplicates = True)

# %% [markdown]
# Add Prediction Outcome

# %%
col_new = 'prediction_team_pronosoft_outcome'
col_next_to = 'prediction_team_pronosoft'

col_match_outcome = get_col_prediction_team_outcome(df_pronosoft_data['prediction_team_pronosoft'], df_pronosoft_data['match_outcome'])
df_pronosoft_data.insert(loc = find_insert_loc(col_next_to), column = col_new, value = col_match_outcome, allow_duplicates = True)

# %%
col_new = 'prediction_uo_pronosoft_outcome'
col_next_to = 'prediction_uo_pronosoft'

col_match_outcome = get_col_prediction_uo_outcome(df_pronosoft_data['prediction_uo_pronosoft'], df_pronosoft_data['team_1_score'], df_pronosoft_data['team_2_score'])
df_pronosoft_data.insert(loc = find_insert_loc(col_next_to), column = col_new, value = col_match_outcome, allow_duplicates = True)

# %% [markdown]
# Get Probabilities of outcome from Betting Odds

# %% [markdown]
# **Note**: We can calculate the Probability of Outcome from Betting Odds, which reflects Bookmakers belief & predictions about outcomes.
#
# Here is an example for Team 1:
#
# \begin{equation*}
# Prob\ (Team\_1) =
# \frac{1} { Team\_1\_odd \times(\frac{1}{Team\_1\_odd} + \frac{1}{Nul\_odd} + \frac{1}{Team\_2\_odd})}
# \end{equation*}

# %%
col_new = 'team_1_prob_from_odds'
col_next_to = 'team_1_prob'

col_prob_from_odds = get_col_prob_from_odds(df_pronosoft_data['team_1_bet_odds'], df_pronosoft_data['nul_bet_odds'], df_pronosoft_data['team_2_bet_odds'])
df_pronosoft_data.insert(loc = find_insert_loc(col_next_to), column = col_new, value = col_prob_from_odds, allow_duplicates = True)

# %%
col_new = 'nul_prob_from_odds'
col_next_to = 'nul_prob'

col_prob_from_odds = get_col_prob_from_odds(df_pronosoft_data['nul_bet_odds'], df_pronosoft_data['team_1_bet_odds'], df_pronosoft_data['team_2_bet_odds'])
df_pronosoft_data.insert(loc = find_insert_loc(col_next_to), column = col_new, value = col_prob_from_odds, allow_duplicates = True)

# %%
col_new = 'team_2_prob_from_odds'
col_next_to = 'team_2_prob'

col_prob_from_odds = get_col_prob_from_odds(df_pronosoft_data['team_2_bet_odds'], df_pronosoft_data['team_1_bet_odds'], df_pronosoft_data['nul_bet_odds'])
df_pronosoft_data.insert(loc = find_insert_loc(col_next_to), column = col_new, value = col_prob_from_odds, allow_duplicates = True)

# %% [markdown]
# Get EV from Betting Odds

# %%
col_new = 'team_1_ev_from_odds'
col_next_to = 'team_1_ev'

col_ev = get_col_ev(df_pronosoft_data['team_1_prob_from_odds'], df_pronosoft_data['team_1_bet_odds'])
df_pronosoft_data.insert(loc = find_insert_loc(col_next_to), column = col_new, value = col_ev, allow_duplicates = True)

# %%
col_new = 'nul_ev_from_odds'
col_next_to = 'nul_ev'

col_ev = get_col_ev(df_pronosoft_data['nul_prob_from_odds'], df_pronosoft_data['nul_bet_odds'])
df_pronosoft_data.insert(loc = find_insert_loc(col_next_to), column = col_new, value = col_ev, allow_duplicates = True)

# %%
col_new = 'team_2_ev_from_odds'
col_next_to = 'team_2_ev'

col_ev = get_col_ev(df_pronosoft_data['team_2_prob_from_odds'], df_pronosoft_data['team_2_bet_odds'])
df_pronosoft_data.insert(loc = find_insert_loc(col_next_to), column = col_new, value = col_ev, allow_duplicates = True)

# %% [markdown]
# ---

# %% [markdown]
# # Save to CSV | Extended Data

# %%
df_pronosoft_data.to_csv(csv_name_extended, index = False)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)

# %%
df_pronosoft_data.to_sql('Football_Data_Extended', con = engine)

# %%
engine.execute("SELECT * FROM Football_Data_Extended").fetchall()
# Out:
# [(0, '01-10-2018', 'France - Ligue 2', '20:45', 'Troyes', 'Auxerre', 0.39, 0.35, 2.75, 0.07, -0.04, 0.18, 0.31, 3.1, -0.44, -0.04, 0.43, 0.34, 2.8, 0.2, -0.05, None, None, 0.68, 1.46, -0.01, 0.32, 2.0, -0.36, 'U', 1.0, 1, 0, '1'),
#  (1, '01-10-2018', 'Espagne - Liga Espagnole', '21:00', 'Celta Vigo', 'Getafe', 0.33, 0.44, 2.15, -0.29, -0.05, 0.38, 0.3, 3.2, 0.22, -0.04, 0.3, 0.26, 3.6, 0.08, -0.06, 'N', 1.0, 0.51, 1.53, -0.22, 0.49, 1.88, -0.08, None, None, 1, 1, 'N'),
#  (2, '01-10-2018', 'Angleterre - Premier League', '21:00', 'Bournemouth', 'Crystal Palace', 0.39, 0.43, 2.2, -0.14, -0.05, 0.25, 0.28, 3.4, -0.15, -0.05, 0.36, 0.29, 3.2, 0.15, -0.07, None, None, 0.4, 1.85, -0.26, 0.6, 1.65, -0.01, 'O', 1.0, 2, 1, '1'),
#  (3, '01-10-2018', 'Italie - Serie A', '20:30', 'Sampdoria', 'Spal', 0.41, 0.54, 1.72, -0.29, -0.07, 0.25, 0.27, 3.5, -0.12, -0.05, 0.33, 0.19, 4.8, 0.58, -0.09, None, None, 0.57, 1.67, -0.05, 0.43, 1.85, -0.2, None, None, 2, 1, '1'),
#  (4, '01-10-2018', 'Portugal - Primeira Liga', '21:15', 'Aves', 'Portimonense', 0.4, 0.35, 2.6, 0.04, -0.09, 0.3, 0.28, 3.25, -0.03, -0.09, 0.3, 0.37, 2.45, -0.26, -0.09, None, None, 0.69, 1.66, 0.15, 0.31, 1.73, -0.46, 'U', 0.0, 3, 0, '1'),
#  (5, '01-10-2018', 'Allemagne - Bundesliga 2', '20:30', 'FC Ingolstadt 04', 'Union Berlin', 0.28, 0.39, 2.25, -0.37, -0.12, 0.43, 0.29, 3.05, 0.31, -0.12, 0.3, 0.32, 2.75, -0.17, -0.12, 'N', 0.0, 0.64, 1.66, 0.06, 0.36, 1.73, -0.38, 'U', 0.0, 1, 2, '2'),
#  (6, '01-10-2018', 'Argentine - Primera Division - Superligue Argentine', '01:00', 'Boca Juniors', 'Colon Santa Fe', 0.48, 0.58, 1.56, -0.25, -0.1, 0.26, 0.27, 3.35, -0.13, -0.1, 0.25, 0.15, 6.25, 0.56, -0.06, None, None, 0.57, 1.42, -0.19, 0.43, 2.1, -0.1, None, None, 3, 1, '1'),
#  (7, '01-10-2018', 'Argentine - Primera Division - Superligue Argentine', '00:00', 'Godoy Cruz', 'Defensa Y Justicia', 0.36, 0.32, 2.75, -0.01, -0.12, 0.27, 0.32, 2.7, -0.27, -0.14, 0.37, 0.36, 2.45, -0.09, -0.12, None, None, 0.72, 1.3, -0.06, 0.28, 2.45, -0.31, 'U', 1.0, 0, 1, '2'),
#  (8, '01-10-2018', 'Argentine - Primera Division - Superligue Argentine', '02:15', 'San Martin Tucuman', 'Banfield', 0.36, 0.39, 2.25, -0.19, -0.12, 0.42, 0.33, 2.65, 0.11, -0.13, 0.22, 0.28, 3.1, -0.32, -0.13, 'N', 1.0, 0.78, 1.3, 0.01, 0.22, 2.45, -0.46, 'U', 1.0, 1, 1, 'N'),
#  (9, '01-10-2018', 'Argentine - Primera Division - Superligue Argentine', '02:15', 'Velez Sarsfield', 'Aldosivi', 0.37, 0.55, 1.58, -0.42, -0.13, 0.26, 0.28, 3.1, -0.19, -0.13, 0.37, 0.16, 5.3, 0.96, -0.15, None, None, 0.78, 1.37, 0.07, 0.22, 2.2, -0.52, 'U', 1.0, 2, 0, '1'),
#  (10, '01-10-2018', 'Biélorussie - Division 1', '17:30', 'FC Neman Grodno', 'FC Gomel', 0.37, 0.49, 1.76, -0.35, -0.14, 0.19, 0.31, 2.8, -0.47, -0.13, 0.44, 0.2, 4.4, 0.94, -0.12, None, None, 0.61, 1.3, -0.21, 0.39, 2.45, -0.04, 'U', 1.0, 2, 0, '1'),
#  (11, '01-10-2018', 'Brésil - Serie A', '00:00', 'Ceara', 'Chapecoense', 0.48, 0.48, 1.85, -0.11, -0.11, 0.41, 0.31, 2.85, 0.17, -0.12, 0.11, 0.21, 4.1, -0.55, -0.14, '1N', 1.0, 0.68, 1.32, -0.1, 0.32, 2.35, -0.25, 'U', 0.0, 3, 1, '1'),
#  (12, '01-10-2018', 'Brésil - Serie A', '01:00', 'Parana', 'Vasco Da Gama', 0.35, 0.33, 2.65, -0.07, -0.13, 0.47, 0.32, 2.75, 0.29, -0.12, 0.18, 0.35, 2.5, -0.55, -0.13, 'N', 1.0, 0.69, 1.35, -0.07, 0.31, 2.2, -0.32, 'U', 1.0, 1, 1, 'N'),
#  (13, '01-10-2018', 'Bulgarie - Division 1 - Division 1 Pro', '19:00', 'Slavia Sofia', 'Botev Vratsa', 0.36, 0.48, 1.82, -0.34, -0.13, 0.38, 0.3, 2.85, 0.08, -0.14, 0.26, 0.22, 3.9, 0.01, -0.14, '1N', 0.0, 0.83, 1.37, 0.14, 0.17, 2.2, -0.63, 'U', 1.0, 0, 1, '2'),
#  (14, '01-10-2018', 'Chili - Primera Division', '01:00', 'Union Espanola', 'Curico Unido', 0.48, 0.43, 2.07, -0.01, -0.11, 0.42, 0.3, 2.95, 0.24, -0.11, 0.1, 0.27, 3.3, -0.67, -0.11, '1N', 1.0, 0.46, 1.55, -0.29, 0.54, 1.85, 0.0, None, None, 2, 1, '1'),
#  (15, '01-10-2018', 'Croatie - Division 1', '18:00', 'Rudes', 'Istra 1961', 0.37, 0.39, 2.22, -0.18, -0.13, 0.27, 0.29, 2.95, -0.2, -0.14, 0.36, 0.32, 2.7, -0.03, -0.14, None, None, 0.5, 1.58, -0.21, 0.5, 1.8, -0.1, None, None, 0, 3, '2'),
#  (16, '01-10-2018', 'Danemark - Superligaen', '19:00', 'FC Nordsjaelland', 'Sonderjyske', 0.45, 0.5, 1.78, -0.2, -0.11, 0.27, 0.26, 3.45, -0.07, -0.1, 0.28, 0.24, 3.7, 0.04, -0.11, None, None, 0.5, 2.05, 0.02, 0.5, 1.53, -0.24, None, None, 4, 1, '1'),
#  (17, '01-10-2018', 'Equateur - Division 1 - Division 1 Stage 2', '02:30', 'Macara', 'El Nacional', 0.6, 0.56, 1.55, -0.07, -0.13, 0.18, 0.24, 3.6, -0.35, -0.14, 0.22, 0.2, 4.35, -0.04, -0.13, '1', 0.0, 0.46, 1.83, -0.16, 0.54, 1.56, -0.16, None, None, 2, 2, 'N'),
#  (18, '01-10-2018', 'Grèce - Super League', '18:00', 'Lamia', 'Xanthi FC', 0.32, 0.37, 2.38, -0.24, -0.12, 0.33, 0.34, 2.55, -0.16, -0.13, 0.36, 0.29, 3.0, 0.08, -0.13, None, None, 0.5, 1.28, -0.36, 0.5, 2.6, 0.3, None, None, 0, 0, 'N'),
#  (19, '01-10-2018', 'Géorgie - Division 1', '13:30', 'Sioni Bolnisi', 'Chikhura Sachkhere', 0.07, 0.24, 3.7, -0.74, -0.11, 0.23, 0.28, 3.1, -0.29, -0.13, 0.7, 0.48, 1.8, 0.26, -0.14, '2', 1.0, 0.66, 1.6, 0.06, 0.34, 1.78, -0.39, 'U', 0.0, 1, 2, '2'),
#  (20, '01-10-2018', 'Géorgie - Division 1', '17:00', 'FC Saburtalo', 'Samtredia', 0.84, 0.76, 1.17, -0.02, -0.11, 0.11, 0.16, 5.4, -0.41, -0.14, 0.05, 0.07, 12.0, -0.4, -0.16, '1', 0.0, 0.38, 1.85, -0.3, 0.62, 1.55, -0.04, 'O', 0.0, 1, 1, 'N'),
#  (21, '01-10-2018', 'Israël - Division 1', '18:00', 'Bnei Yehuda Tel Aviv', 'Hapoel Raanana', 0.34, 0.4, 2.15, -0.27, -0.14, 0.41, 0.31, 2.82, 0.16, -0.13, 0.25, 0.29, 3.0, -0.25, -0.13, 'N', 0.0, 0.55, 1.42, -0.22, 0.45, 2.1, -0.05, None, None, 3, 0, '1'),
#  (22, '01-10-2018', 'Israël - Division 1', '19:00', 'Maccabi Haifa', 'Hapoel Beer Sheva', 0.4, 0.31, 2.78, 0.11, -0.14, 0.3, 0.3, 2.9, -0.13, -0.13, 0.3, 0.39, 2.2, -0.34, -0.14, None, None, 0.67, 1.6, 0.07, 0.34, 1.78, -0.39, 'U', 1.0, 0, 0, 'N'),
#  (23, '01-10-2018', 'Israël - Division 1', '20:00', 'Maccabi Tel Aviv', 'Hapoel Tel Aviv', 0.63, 0.67, 1.3, -0.18, -0.13, 0.21, 0.22, 4.0, -0.16, -0.12, 0.16, 0.11, 7.75, 0.24, -0.15, '1', 0.0, 0.54, 1.7, -0.08, 0.47, 1.7, -0.2, None, None, 0, 0, 'N'),
#  (24, '01-10-2018', 'Luxembourg - Division 1', '20:00', 'Fola Esch', 'Progres Niederkorn', 0.43, 0.33, 2.65, 0.14, -0.13, 0.22, 0.23, 3.7, -0.19, -0.15, 0.35, 0.44, 1.97, -0.31, -0.13, None, None, 0.5, 2.75, 0.38, 0.5, 1.22, -0.39, None, None, 2, 1, '1'),
#  (25, '01-10-2018', 'Mexique - Liga MX - Apertura', '01:05', 'Club America', 'Guadalajara', 0.37, 0.55, 1.58, -0.42, -0.13, 0.25, 0.26, 3.35, -0.16, -0.13, 0.38, 0.19, 4.55, 0.73, -0.14, None, None, 0.31, 1.62, -0.5, 0.69, 1.76, 0.21, 'O', 0.0, 1, 1, 'N'),
#  (26, '01-10-2018', 'Norvège - Eliteserien', '19:00', 'Tromso', 'Brann', 0.16, 0.33, 2.63, -0.58, -0.13, 0.34, 0.29, 3.0, 0.02, -0.13, 0.5, 0.38, 2.25, 0.12, -0.15, None, None, 0.45, 1.66, -0.25, 0.55, 1.73, -0.05, None, None, 2, 1, '1'),
#  (27, '01-10-2018', 'Paraguay - Division 1  - Clausura', '01:40', 'Sportivo Luqueno', 'Libertad', 0.06, 0.27, 3.2, -0.81, -0.14, 0.27, 0.28, 3.05, -0.18, -0.15, 0.67, 0.45, 1.88, 0.26, -0.15, '2', 0.0, 0.65, 1.55, 0.01, 0.35, 1.85, -0.35, 'U', 1.0, 0, 0, 'N'),
#  (28, '01-10-2018', 'Paraguay - Division 1  - Clausura', '01:00', 'General Diaz', '3 De Febrero', 0.43, 0.4, 2.15, -0.08, -0.14, 0.31, 0.3, 2.9, -0.1, -0.13, 0.27, 0.3, 2.85, -0.23, -0.14, None, None, 0.61, 1.55, -0.05, 0.39, 1.85, -0.28, 'U', 0.0, 1, 5, '2'),
#  (29, '01-10-2018', 'Pologne - Division 1', '18:00', 'Jagiellonia', 'Slask Wroclaw', 0.59, 0.49, 1.81, 0.07, -0.11, 0.22, 0.27, 3.2, -0.3, -0.14, 0.2, 0.24, 3.65, -0.27, -0.12, '1', 0.0, 0.34, 1.66, -0.44, 0.66, 1.73, 0.14, 'O', 1.0, 0, 4, '2'),
#  (30, '01-10-2018', 'Roumanie - Liga I - Ligue 1', '17:00', 'Concordia', 'Dunarea Calarasi', 0.31, 0.38, 2.28, -0.29, -0.13, 0.35, 0.31, 2.8, -0.02, -0.13, 0.34, 0.31, 2.78, -0.05, -0.14, None, None, 0.64, 1.44, -0.08, 0.36, 2.05, -0.26, 'U', 1.0, 1, 1, 'N'),
#  (31, '01-10-2018', 'Roumanie - Liga I - Ligue 1', '20:00', 'CFR 1907 Cluj', 'Cs Universitatea Craiova', 0.34, 0.53, 1.63, -0.45, -0.14, 0.27, 0.28, 3.1, -0.16, -0.13, 0.39, 0.19, 4.6, 0.79, -0.13, None, None, 0.46, 1.46, -0.33, 0.54, 2.0, 0.08, None, None, 0, 0, 'N'),
#  (32, '01-10-2018', 'Russie - Premier League', '18:30', 'Rubin Kazan', 'Krylya Sovetov', 0.41, 0.55, 1.6, -0.34, -0.12, 0.26, 0.29, 3.0, -0.22, -0.13, 0.33, 0.16, 5.6, 0.85, -0.1, None, None, 0.67, 1.32, -0.12, 0.33, 2.35, -0.22, 'U', 0.0, 2, 1, '1'),
#  (33, '01-10-2018', 'Slovénie - Division 1', '16:00', 'Nd Gorica', 'Nk Cm Celje', 0.38, 0.34, 2.55, -0.03, -0.13, 0.42, 0.29, 2.95, 0.24, -0.14, 0.2, 0.37, 2.33, -0.53, -0.14, '1N', 1.0, 0.64, 1.62, 0.04, 0.36, 1.76, -0.37, 'U', 1.0, 1, 1, 'N'),
#  (34, '01-10-2018', 'Slovénie - Division 1', '18:00', 'Aluminij', 'Triglav Kranj', 0.25, 0.52, 1.69, -0.58, -0.12, 0.37, 0.26, 3.3, 0.22, -0.14, 0.38, 0.22, 4.0, 0.52, -0.12, 'N2', 0.0, 0.47, 1.66, -0.22, 0.53, 1.73, -0.08, None, None, 2, 0, '1'),
#  (35, '01-10-2018', 'Suède - Allsvenskan', '19:00', 'Hammarby', 'IFK Göteborg', 0.76, 0.63, 1.42, 0.08, -0.11, 0.07, 0.22, 4.1, -0.71, -0.1, 0.17, 0.15, 5.9, 0.0, -0.12, '1', 1.0, 0.38, 1.96, -0.26, 0.62, 1.48, -0.08, 'O', 1.0, 3, 0, '1'),
#  (36, '01-10-2018', 'Suède - Allsvenskan', '19:00', 'If Elfsborg', 'Hacken', 0.31, 0.31, 2.78, -0.14, -0.14, 0.28, 0.28, 3.15, -0.12, -0.12, 0.41, 0.41, 2.12, -0.13, -0.13, None, None, 0.7, 1.78, 0.25, 0.3, 1.6, -0.52, 'U', 0.0, 0, 3, '2'),
#  (37, '01-10-2018', 'Suède - Allsvenskan', '19:00', 'Örebro', 'Trelleborgs Ff', 0.46, 0.58, 1.55, -0.29, -0.1, 0.29, 0.24, 3.8, 0.1, -0.09, 0.25, 0.18, 5.1, 0.27, -0.08, None, None, 0.65, 1.85, 0.2, 0.35, 1.55, -0.46, 'U', 0.0, 4, 0, '1'),
#  (38, '01-10-2018', 'Turquie - Super Lig - Super Ligue', '19:00', 'Ankaragucu', 'Antalyaspor', 0.39, 0.43, 2.02, -0.21, -0.13, 0.26, 0.28, 3.05, -0.21, -0.15, 0.35, 0.28, 3.05, 0.07, -0.15, None, None, 0.49, 1.66, -0.19, 0.51, 1.73, -0.12, None, None, 0, 1, '2'),
#  (39, '01-10-2018', 'Turquie - Super Lig - Super Ligue', '19:00', 'Istanbul Basaksehir', 'Yeni Malatyaspor', 0.49, 0.61, 1.48, -0.27, -0.1, 0.24, 0.25, 3.6, -0.14, -0.1, 0.26, 0.14, 6.25, 0.62, -0.12, None, None, 0.5, 1.66, -0.17, 0.5, 1.73, -0.14, None, None, 1, 1, 'N'),
#  (40, '02-10-2018', 'France - Ligue 2', '19:00', 'Béziers', 'Lens', 0.13, 0.22, 4.2, -0.45, -0.08, 0.18, 0.29, 3.15, -0.43, -0.09, 0.68, 0.49, 1.9, 0.29, -0.07, '2', 0.0, 0.69, 1.44, -0.01, 0.31, 2.05, -0.36, 'U', 1.0, 0, 0, 'N'),
#  (41, '02-10-2018', 'Angleterre - Championship', '20:45', 'Aston Villa', 'Preston', 0.69, 0.52, 1.72, 0.19, -0.11, 0.19, 0.27, 3.3, -0.37, -0.11, 0.12, 0.21, 4.3, -0.48, -0.1, '1', 0.0, 0.47, 1.65, -0.22, 0.53, 1.78, -0.06, None, None, 3, 3, 'N'),
#  (42, '02-10-2018', 'Angleterre - Championship', '20:45', 'Brentford', 'Birmingham', 0.45, 0.56, 1.58, -0.29, -0.12, 0.35, 0.25, 3.5, 0.22, -0.12, 0.2, 0.18, 4.9, -0.02, -0.12, None, None, 0.37, 1.78, -0.34, 0.63, 1.65, 0.04, 'O', 0.0, 1, 1, 'N'),
#  (43, '02-10-2018', 'Angleterre - Championship', '20:45', 'Hull City', 'Leeds', 0.09, 0.28, 3.1, -0.72, -0.13, 0.3, 0.28, 3.2, -0.04, -0.1, 0.62, 0.44, 2.0, 0.24, -0.12, '2', 1.0, 0.66, 1.83, 0.21, 0.34, 1.6, -0.46, 'U', 1.0, 0, 1, '2'),
#  (44, '02-10-2018', 'Angleterre - Championship', '20:45', 'Ipswich', 'Middlesbrough', 0.2, 0.23, 3.75, -0.25, -0.14, 0.5, 0.31, 2.8, 0.4, -0.13, 0.3, 0.46, 1.9, -0.43, -0.13, 'N', 0.0, 0.69, 1.42, -0.02, 0.31, 2.25, -0.3, 'U', 1.0, 0, 2, '2'),
#  (45, '02-10-2018', 'Angleterre - Championship', '20:45', 'Wigan', 'Swansea', 0.39, 0.45, 1.95, -0.24, -0.12, 0.34, 0.29, 3.0, 0.02, -0.13, 0.27, 0.25, 3.5, -0.05, -0.12, '1N', 1.0, 0.48, 1.6, -0.23, 0.52, 1.85, -0.04, None, None, 0, 0, 'N'),
#  (46, '02-10-2018', 'Angleterre - Championship', '21:00', 'Reading', 'Queens Park Rangers', 0.35, 0.38, 2.3, -0.2, -0.13, 0.21, 0.3, 2.95, -0.38, -0.11, 0.44, 0.32, 2.8, 0.23, -0.1, None, None, 0.61, 1.6, -0.02, 0.39, 1.85, -0.28, 'U', 1.0, 0, 1, '2'),
#  (47, '02-10-2018', 'Angleterre - Championship', '21:00', 'Stoke City', 'Bolton', 0.26, 0.61, 1.44, -0.63, -0.12, 0.33, 0.24, 3.7, 0.22, -0.11, 0.41, 0.15, 6.0, 1.46, -0.1, None, None, 0.62, 1.72, 0.07, 0.38, 1.7, -0.35, 'U', 1.0, 2, 0, '1'),
#  (48, '02-10-2018', 'Argentine - Primera Division - Superligue Argentine', '00:00', 'Godoy Cruz', 'Defensa Y Justicia', 0.36, 0.32, 2.75, -0.01, -0.12, 0.27, 0.32, 2.7, -0.27, -0.14, 0.37, 0.36, 2.45, -0.09, -0.12, None, None, 0.72, 1.3, -0.06, 0.28, 2.45, -0.31, 'U', 1.0, 0, 1, '2'),
#  (49, '02-10-2018', 'Argentine - Primera Division - Superligue Argentine', '02:15', 'San Martin Tucuman', 'Banfield', 0.36, 0.39, 2.25, -0.19, -0.12, 0.42, 0.33, 2.65, 0.11, -0.13, 0.22, 0.28, 3.1, -0.32, -0.13, 'N', 1.0, 0.78, 1.3, 0.01, 0.22, 2.45, -0.46, 'U', 1.0, 1, 1, 'N'),
#  (50, '02-10-2018', 'Argentine - Primera Division - Superligue Argentine', '02:15', 'Velez Sarsfield', 'Aldosivi', 0.37, 0.55, 1.58, -0.42, -0.13, 0.26, 0.28, 3.1, -0.19, -0.13, 0.37, 0.16, 5.3, 0.96, -0.15, None, None, 0.78, 1.37, 0.07, 0.22, 2.2, -0.52, 'U', 1.0, 2, 0, '1'),
#  (51, '02-10-2018', 'Brésil - Serie A', '01:00', 'Parana', 'Vasco Da Gama', 0.35, 0.33, 2.65, -0.07, -0.13, 0.47, 0.32, 2.75, 0.29, -0.12, 0.18, 0.35, 2.5, -0.55, -0.13, 'N', 1.0, 0.69, 1.35, -0.07, 0.31, 2.2, -0.32, 'U', 1.0, 1, 1, 'N'),
#  (52, '02-10-2018', 'Equateur - Division 1 - Division 1 Stage 2', '02:30', 'Macara', 'El Nacional', 0.6, 0.56, 1.55, -0.07, -0.13, 0.18, 0.24, 3.6, -0.35, -0.14, 0.22, 0.2, 4.35, -0.04, -0.13, '1', 0.0, 0.46, 1.83, -0.16, 0.54, 1.56, -0.16, None, None, 2, 2, 'N'),
#  (53, '02-10-2018', 'Estonie - Division 1', '17:30', 'Kuressaare', 'Paide Linnameeskond', 0.06, 0.15, 5.9, -0.65, -0.12, 0.05, 0.18, 5.0, -0.75, -0.1, 0.89, 0.67, 1.32, 0.17, -0.12, '2', 1.0, 0.41, 3.3, 0.35, 0.59, 1.13, -0.33, None, None, 1, 3, '2'),
#  (54, '02-10-2018', 'Estonie - Division 1', '19:30', 'Parnu Jk Vaprus', 'Tulevik Viljandi', 0.51, 0.32, 2.88, 0.47, -0.08, 0.15, 0.27, 3.35, -0.5, -0.1, 0.35, 0.41, 2.25, -0.21, -0.08, None, None, 0.44, 2.35, 0.03, 0.56, 1.32, -0.26, None, None, 0, 3, '2'),
#  (55, '02-10-2018', 'Géorgie - Division 1', '13:30', 'Metalurgi Rustavi', 'Lokomotivi Tbilisi', 0.3, 0.37, 2.33, -0.3, -0.14, 0.23, 0.3, 2.95, -0.32, -0.11, 0.47, 0.33, 2.65, 0.25, -0.13, None, None, 0.7, 1.5, 0.05, 0.3, 1.92, -0.42, 'U', 1.0, 1, 1, 'N'),
#  (56, '02-10-2018', 'Italie - Serie B', '17:35', 'Padova', 'Pescara', 0.34, 0.38, 2.3, -0.22, -0.13, 0.41, 0.31, 2.85, 0.17, -0.12, 0.25, 0.31, 2.8, -0.3, -0.13, 'N', 1.0, 0.82, 1.48, 0.21, 0.18, 1.96, -0.65, 'U', 0.0, 2, 2, 'N'),
#  (57, '02-10-2018', 'Paraguay - Division 1  - Clausura', '01:00', 'General Diaz', '3 De Febrero', 0.43, 0.4, 2.15, -0.08, -0.14, 0.31, 0.3, 2.9, -0.1, -0.13, 0.27, 0.3, 2.85, -0.23, -0.14, None, None, 0.61, 1.55, -0.05, 0.39, 1.85, -0.28, 'U', 0.0, 1, 5, '2'),
#  (58, '03-10-2018', 'Albanie - Superliga', '13:45', 'Kastrioti Kruje', 'Tirana', 0.33, 0.16, 5.4, 0.78, -0.14, 0.36, 0.23, 3.7, 0.33, -0.15, 0.32, 0.61, 1.38, -0.56, -0.16, None, None, 0.72, 1.73, 0.25, 0.29, 1.66, -0.52, 'U', 0.0, 2, 3, '2'),
#  (59, '03-10-2018', 'Albanie - Superliga', '13:45', 'Laci', 'Flamurtari Vlore', 0.36, 0.49, 1.78, -0.36, -0.13, 0.34, 0.32, 2.75, -0.06, -0.12, 0.29, 0.19, 4.5, 0.3, -0.15, '1N', 1.0, 0.81, 1.26, 0.02, 0.19, 2.6, -0.51, 'U', 1.0, 1, 0, '1'),
#  (60, '03-10-2018', 'Albanie - Superliga', '13:45', 'Luftetari Gjirokaster', 'Kamza', 0.39, 0.45, 1.9, -0.26, -0.15, 0.22, 0.31, 2.75, -0.4, -0.15, 0.39, 0.24, 3.5, 0.37, -0.16, None, None, 0.68, 1.32, -0.1, 0.32, 2.35, -0.25, 'U', 1.0, 1, 0, '1'),
#  (61, '03-10-2018', 'Albanie - Superliga', '16:45', 'Partizani', 'Teuta Durres', 0.61, 0.62, 1.39, -0.15, -0.14, 0.22, 0.25, 3.5, -0.23, -0.12, 0.17, 0.13, 6.5, 0.11, -0.15, '1', 1.0, 0.85, 1.44, 0.22, 0.16, 2.05, -0.67, 'U', 0.0, 3, 0, '1'),
#  (62, '03-10-2018', 'Angleterre - Championship', '20:45', 'Blackburn', 'Sheffield Utd', 0.22, 0.31, 2.95, -0.35, -0.09, 0.38, 0.3, 3.05, 0.16, -0.09, 0.4, 0.4, 2.25, -0.1, -0.1, 'N2', 1.0, 0.62, 1.66, 0.03, 0.38, 1.85, -0.3, 'U', 1.0, 0, 2, '2'),
#  (63, '03-10-2018', 'Angleterre - Championship', '20:45', 'Derby', 'Norwich', 0.35, 0.46, 1.9, -0.34, -0.13, 0.31, 0.28, 3.1, -0.04, -0.13, 0.34, 0.25, 3.5, 0.19, -0.12, None, None, 0.51, 1.67, -0.15, 0.49, 1.75, -0.14, None, None, 1, 1, 'N'),
#  (64, '03-10-2018', 'Angleterre - Championship', '20:45', 'Nottingham', 'Millwall', 0.69, 0.51, 1.72, 0.19, -0.12, 0.24, 0.27, 3.2, -0.23, -0.14, 0.07, 0.22, 4.0, -0.72, -0.12, '1', 0.0, 0.62, 1.6, -0.01, 0.38, 1.85, -0.3, 'U', 0.0, 2, 2, 'N'),
#  (65, '03-10-2018', 'Angleterre - Championship', '20:45', 'Rotherham', 'Bristol City', 0.39, 0.26, 3.4, 0.33, -0.12, 0.27, 0.28, 3.2, -0.14, -0.1, 0.35, 0.46, 1.9, -0.34, -0.13, None, None, 0.51, 1.7, -0.13, 0.49, 1.78, -0.13, None, None, 0, 0, 'N'),
#  (66, '03-10-2018', 'Angleterre - Championship', '20:45', 'Sheffield Wed', 'West Brom', 0.27, 0.25, 3.45, -0.07, -0.14, 0.42, 0.26, 3.35, 0.41, -0.13, 0.31, 0.49, 1.8, -0.44, -0.12, 'N', 1.0, 0.31, 1.92, -0.4, 0.69, 1.6, 0.1, 'O', 1.0, 2, 2, 'N'),
#  (67, '03-10-2018', 'Arménie - Division 1', '17:00', 'Pyunik Yerevan', 'Gandzasar', 0.6, 0.49, 1.75, 0.05, -0.14, 0.22, 0.28, 3.05, -0.33, -0.15, 0.18, 0.23, 3.8, -0.32, -0.13, '1', 0.0, 0.38, 1.56, -0.41, 0.62, 1.83, 0.13, 'O', 0.0, 0, 1, '2'),
#  (68, '03-10-2018', 'Equateur - Division 1 - Division 1 Stage 2', '00:00', 'Guayaquil City FC', 'Independ. Del Valle', 0.15, 0.2, 4.3, -0.36, -0.14, 0.41, 0.28, 3.1, 0.27, -0.13, 0.43, 0.52, 1.68, -0.28, -0.13, None, None, 0.66, 1.53, 0.01, 0.34, 1.88, -0.36, 'U', 0.0, 1, 2, '2'),
#  (69, '03-10-2018', 'Equateur - Division 1 - Division 1 Stage 2', '02:15', 'Ldu Quito', 'Univ. Catolica', 0.44, 0.42, 2.08, -0.08, -0.13, 0.33, 0.3, 2.9, -0.04, -0.13, 0.23, 0.28, 3.05, -0.3, -0.15, None, None, 0.72, 1.5, 0.08, 0.28, 1.92, -0.46, 'U', 1.0, 1, 0, '1'),
#  (70, '03-10-2018', 'Estonie - Division 1', '18:00', 'Trans Narva', 'Tallinna Kalev', 0.8, 0.52, 1.66, 0.33, -0.14, 0.13, 0.24, 3.6, -0.53, -0.14, 0.07, 0.24, 3.65, -0.74, -0.12, '1', 1.0, 0.28, 2.25, -0.37, 0.72, 1.35, -0.03, 'O', 1.0, 3, 2, '1'),
#  (71, '03-10-2018', 'Estonie - Division 1', '18:30', 'Fci Levadia', 'Kalju Nomme', 0.16, 0.39, 2.2, -0.65, -0.14, 0.26, 0.28, 3.05, -0.21, -0.15, 0.58, 0.32, 2.7, 0.57, -0.14, None, None, 0.22, 1.83, -0.6, 0.78, 1.56, 0.22, 'O', 0.0, 0, 0, 'N'),
#  (72, '03-10-2018', 'Géorgie - Division 1', '17:00', 'Torpedo Kutaisi', 'Dila Gori', 0.36, 0.44, 1.98, -0.29, -0.13, 0.28, 0.28, 3.05, -0.15, -0.15, 0.37, 0.28, 3.05, 0.13, -0.15, None, None, 0.44, 1.62, -0.29, 0.56, 1.76, -0.01, None, None, 2, 0, '1'),
#  (73, '03-10-2018', 'Lettonie - Division 1', '15:00', 'Valmieras', 'Spartaks', 0.05, 0.06, 16.0, -0.2, -0.04, 0.08, 0.11, 8.5, -0.32, -0.07, 0.87, 0.84, 1.08, -0.06, -0.09, '2', 0.0, 0.42, 3.3, 0.39, 0.58, 1.14, -0.34, None, None, 2, 1, '1'),
#  (74, '03-10-2018', 'Lettonie - Division 1', '18:00', 'Rigas Futbola Skola', 'Fk Liepaja', 0.39, 0.41, 2.1, -0.18, -0.14, 0.26, 0.29, 2.95, -0.23, -0.14, 0.35, 0.3, 2.9, 0.01, -0.13, None, None, 0.33, 1.58, -0.48, 0.67, 1.8, 0.21, 'O', 0.0, 0, 1, '2'),
#  (75, '04-10-2018', 'Albanie - Superliga', '17:45', 'Skenderbeu Korce', 'Fk Kukesi', 0.35, 0.43, 2.02, -0.29, -0.13, 0.34, 0.3, 2.95, 0.0, -0.11, 0.31, 0.27, 3.2, -0.01, -0.14, None, None, 0.75, 1.42, 0.06, 0.25, 2.1, -0.48, 'U', 1.0, 1, 0, '1'),
#  (76, '04-10-2018', 'Equateur - Division 1 - Division 1 Stage 2', '00:00', 'Guayaquil City FC', 'Independ. Del Valle', 0.15, 0.2, 4.3, -0.36, -0.14, 0.41, 0.28, 3.1, 0.27, -0.13, 0.43, 0.52, 1.68, -0.28, -0.13, None, None, 0.66, 1.53, 0.01, 0.34, 1.88, -0.36, 'U', 0.0, 1, 2, '2'),
#  (77, '04-10-2018', 'Equateur - Division 1 - Division 1 Stage 2', '02:15', 'Ldu Quito', 'Univ. Catolica', 0.44, 0.42, 2.08, -0.08, -0.13, 0.33, 0.3, 2.9, -0.04, -0.13, 0.23, 0.28, 3.05, -0.3, -0.15, None, None, 0.72, 1.5, 0.08, 0.28, 1.92, -0.46, 'U', 1.0, 1, 0, '1'),
#  (78, '04-10-2018', 'Lituanie - Lyga - Division 1', '15:00', 'Stumbras', 'Lietava Jonava', 0.4, 0.56, 1.57, -0.37, -0.12, 0.26, 0.25, 3.45, -0.1, -0.14, 0.34, 0.19, 4.6, 0.56, -0.13, None, None, 0.68, 1.58, 0.07, 0.32, 1.8, -0.42, 'U', 0.0, 3, 0, '1'),
#  (79, '04-10-2018', 'Lituanie - Lyga - Division 1', '17:00', 'Atlantas', 'Suduva Marijampole', 0.05, 0.06, 16.0, -0.2, -0.04, 0.11, 0.13, 6.75, -0.26, -0.12, 0.84, 0.81, 1.1, -0.08, -0.11, '2', 1.0, 0.66, 2.1, 0.39, 0.34, 1.42, -0.52, 'U', 0.0, 2, 5, '2'),
#  (80, '04-10-2018', 'Lituanie - Lyga - Division 1', '19:00', 'Fk Trakai', 'Fk Zalgiris Vilnius', 0.11, 0.19, 4.6, -0.49, -0.13, 0.26, 0.26, 3.35, -0.13, -0.13, 0.63, 0.55, 1.58, 0.0, -0.13, None, None, 0.6, 1.58, -0.05, 0.4, 1.8, -0.28, 'U', 1.0, 1, 0, '1'),
#  (81, '05-10-2018', 'France - Ligue 1', '20:45', 'Toulouse', 'Nice', 0.3, 0.42, 2.25, -0.32, -0.06, 0.31, 0.29, 3.25, 0.01, -0.06, 0.39, 0.29, 3.25, 0.27, -0.06, None, None, 0.51, 1.7, -0.13, 0.49, 1.9, -0.07, None, None, 1, 1, 'N'),
#  (82, '05-10-2018', 'France - Ligue 2', '20:00', 'Châteauroux', 'Troyes', 0.42, 0.39, 2.42, 0.02, -0.06, 0.29, 0.31, 3.0, -0.13, -0.07, 0.29, 0.3, 3.1, -0.1, -0.07, None, None, 0.7, 1.5, 0.05, 0.3, 1.88, -0.44, 'U', 0.0, 0, 3, '2'),
#  (83, '05-10-2018', 'France - Ligue 2', '20:00', 'GFC Ajaccio', 'Orléans', 0.37, 0.39, 2.4, -0.11, -0.06, 0.27, 0.31, 3.05, -0.18, -0.05, 0.36, 0.3, 3.1, 0.12, -0.07, None, None, 0.62, 1.55, -0.04, 0.38, 1.85, -0.3, 'U', 1.0, 0, 2, '2'),
#  (84, '05-10-2018', 'France - Ligue 2', '20:00', 'Grenoble', 'Clermont Foot', 0.37, 0.42, 2.2, -0.19, -0.08, 0.33, 0.31, 3.0, -0.01, -0.07, 0.31, 0.27, 3.4, 0.05, -0.08, None, None, 0.51, 1.44, -0.27, 0.49, 2.05, 0.0, None, None, 1, 0, '1'),
#  (85, '05-10-2018', 'France - Ligue 2', '20:00', 'Le Havre', 'Béziers', 0.36, 0.6, 1.54, -0.45, -0.08, 0.35, 0.26, 3.6, 0.26, -0.06, 0.29, 0.14, 6.5, 0.88, -0.09, '1N', 0.0, 0.65, 1.42, -0.08, 0.35, 2.1, -0.26, 'U', 0.0, 2, 3, '2'),
#  (86, '05-10-2018', 'France - Ligue 2', '20:00', 'Lorient', 'Nancy', 0.61, 0.62, 1.53, -0.07, -0.05, 0.22, 0.25, 3.7, -0.19, -0.07, 0.17, 0.13, 7.25, 0.23, -0.06, '1', 1.0, 0.79, 1.5, 0.19, 0.21, 1.92, -0.6, 'U', 0.0, 4, 1, '1'),
#  (87, '05-10-2018', 'France - Ligue 2', '20:00', 'Niort', 'Paris FC', 0.35, 0.3, 3.1, 0.08, -0.07, 0.42, 0.32, 2.9, 0.22, -0.07, 0.22, 0.38, 2.45, -0.46, -0.07, 'N', 0.0, 0.49, 1.37, -0.33, 0.51, 2.2, 0.12, None, None, 1, 0, '1'),
#  (88, '05-10-2018', 'France - Ligue 2', '20:00', 'Red Star FC 93', 'Ajaccio', 0.29, 0.36, 2.65, -0.23, -0.05, 0.23, 0.32, 2.9, -0.33, -0.07, 0.47, 0.32, 2.95, 0.39, -0.06, None, None, 0.64, 1.35, -0.14, 0.36, 2.25, -0.19, 'U', 1.0, 2, 0, '1'),
#  (89, '05-10-2018', 'France - Ligue 2', '20:00', 'Valenciennes', 'Brest', 0.21, 0.31, 2.95, -0.38, -0.09, 0.21, 0.28, 3.3, -0.31, -0.08, 0.58, 0.4, 2.3, 0.33, -0.08, '2', 1.0, 0.32, 1.88, -0.4, 0.68, 1.53, 0.04, 'O', 1.0, 1, 3, '2'),
#  (90, '05-10-2018', 'Espagne - Liga Espagnole', '21:00', 'Atheltic Bilbao', 'Real Sociedad', 0.23, 0.48, 1.95, -0.55, -0.06, 0.36, 0.28, 3.3, 0.19, -0.08, 0.41, 0.24, 3.85, 0.58, -0.08, 'N2', 1.0, 0.61, 1.56, -0.05, 0.39, 1.83, -0.29, 'U', 0.0, 1, 3, '2'),
#  (91, '05-10-2018', 'Angleterre - Premier League', '21:00', 'Brighton', 'West Ham', 0.38, 0.36, 2.6, -0.01, -0.06, 0.25, 0.29, 3.2, -0.2, -0.07, 0.36, 0.35, 2.7, -0.03, -0.06, None, None, 0.45, 1.57, -0.29, 0.55, 1.95, 0.07, None, None, 1, 0, '1'),
#  (92, '05-10-2018', 'Italie - Serie A', '20:30', 'Torino', 'Frosinone', 0.6, 0.68, 1.38, -0.17, -0.06, 0.16, 0.21, 4.5, -0.28, -0.06, 0.24, 0.11, 8.75, 1.1, -0.04, '1', 1.0, 0.7, 1.7, 0.19, 0.3, 1.78, -0.47, 'U', 0.0, 3, 2, '1'),
#  (93, '05-10-2018', 'Allemagne - Bundesliga', '20:30', 'Werder Bremen', 'VFL Wolfsburg', 0.28, 0.48, 1.95, -0.45, -0.06, 0.39, 0.26, 3.6, 0.4, -0.06, 0.33, 0.25, 3.7, 0.22, -0.07, 'N', 0.0, 0.42, 1.9, -0.2, 0.59, 1.6, -0.06, 'O', 0.0, 2, 0, '1'),
#  (94, '05-10-2018', 'Portugal - Primeira Liga', '16:30', 'Tondela', 'Nacional', 0.33, 0.48, 1.85, -0.39, -0.11, 0.32, 0.27, 3.3, 0.06, -0.11, 0.35, 0.25, 3.6, 0.26, -0.1, None, None, 0.7, 1.66, 0.16, 0.3, 1.73, -0.48, 'U', 1.0, 1, 1, 'N'),
#  (95, '05-10-2018', 'Portugal - Primeira Liga', '19:00', 'Santa Clara', 'Chaves', 0.41, 0.41, 2.15, -0.12, -0.12, 0.26, 0.29, 3.05, -0.21, -0.12, 0.33, 0.29, 3.05, 0.01, -0.12, None, None, 0.27, 1.55, -0.58, 0.73, 1.85, 0.35, 'O', 0.0, 1, 0, '1'),
#  (96, '05-10-2018', 'Portugal - Primeira Liga', '21:30', 'Feirense', 'Belenenses', 0.27, 0.39, 2.3, -0.38, -0.1, 0.42, 0.32, 2.85, 0.2, -0.09, 0.31, 0.29, 3.05, -0.05, -0.12, 'N', 1.0, 0.81, 1.37, 0.11, 0.19, 2.2, -0.58, 'U', 1.0, 0, 0, 'N'),
#  (97, '05-10-2018', 'Allemagne - Bundesliga 2', '18:30', 'Sv Darmstadt 98', 'Hambourg SV', 0.25, 0.29, 3.0, -0.25, -0.13, 0.3, 0.3, 2.95, -0.11, -0.11, 0.44, 0.41, 2.13, -0.06, -0.13, None, None, 0.52, 1.55, -0.19, 0.49, 1.85, -0.09, None, None, 1, 2, '2'),
#  (98, '05-10-2018', 'Allemagne - Bundesliga 2', '18:30', 'VFL Bochum', 'Arminia Bielefeld', 0.33, 0.42, 2.07, -0.32, -0.13, 0.29, 0.28, 3.1, -0.1, -0.13, 0.38, 0.3, 2.95, 0.12, -0.11, None, None, 0.38, 1.73, -0.34, 0.62, 1.66, 0.03, 'O', 0.0, 1, 0, '1'),
#  (99, '05-10-2018', 'Azerbaïdjan - Division 1', '16:00', 'Zira', 'Qabala', 0.4, 0.25, 3.5, 0.4, -0.12, 0.27, 0.29, 3.05, -0.18, -0.12, 0.33, 0.47, 1.87, -0.38, -0.12, None, None, 0.64, 1.48, -0.05, 0.36, 1.96, -0.29, 'U', 1.0, 1, 0, '1'),
#  (100, '05-10-2018', 'Azerbaïdjan - Division 1', '17:00', 'Sabail', 'Sumqayit', 0.2, 0.24, 3.6, -0.28, -0.14, 0.34, 0.29, 2.95, 0.0, -0.14, 0.46, 0.46, 1.87, -0.14, -0.14, None, None, 0.78, 1.5, 0.17, 0.22, 1.92, -0.58, 'U', 1.0, 2, 0, '1'),
#  (101, '05-10-2018', 'Azerbaïdjan - Division 1', '18:15', 'Neftchi Baku', 'Sabah Fk', 0.39, 0.71, 1.23, -0.52, -0.13, 0.25, 0.19, 4.6, 0.15, -0.13, 0.36, 0.1, 8.5, 2.06, -0.15, None, None, 0.5, 1.6, -0.2, 0.5, 1.78, -0.11, None, None, 2, 0, '1'),
#  (102, '05-10-2018', 'Belgique - Division 1', '20:30', 'Cercle Bruges', 'Charleroi', 0.31, 0.33, 2.65, -0.18, -0.13, 0.29, 0.29, 3.05, -0.12, -0.12, 0.41, 0.38, 2.28, -0.07, -0.13, None, None, 0.41, 1.66, -0.32, 0.59, 1.73, 0.02, None, None, 2, 1, '1'),
#  (103, '05-10-2018', 'Biélorussie - Division 1', '15:00', 'Torpedo Minsk', 'FC Minsk', 0.17, 0.23, 3.7, -0.37, -0.15, 0.37, 0.29, 3.0, 0.11, -0.13, 0.46, 0.48, 1.82, -0.16, -0.13, 'N2', 0.0, 0.64, 1.42, -0.09, 0.36, 2.1, -0.24, 'U', 1.0, 1, 0, '1'),
#  (104, '05-10-2018', 'Biélorussie - Division 1', '18:00', 'Gorodeya', 'FC Luch Minsk', 0.36, 0.42, 2.05, -0.26, -0.14, 0.36, 0.31, 2.75, -0.01, -0.15, 0.28, 0.26, 3.3, -0.08, -0.14, '1N', 1.0, 0.7, 1.35, -0.05, 0.3, 2.25, -0.32, 'U', 1.0, 1, 1, 'N'),
#  (105, '05-10-2018', 'Bosnie-Herzégovine - Division 1', '18:00', 'Zeljeznicar Sarajevo', 'Nk Celik Zenica', 0.42, 0.71, 1.24, -0.48, -0.12, 0.43, 0.18, 4.9, 1.11, -0.12, 0.15, 0.1, 8.5, 0.28, -0.15, '1N', 1.0, 0.67, 1.66, 0.11, 0.33, 1.73, -0.43, 'U', 0.0, 3, 2, '1'),
#  (106, '05-10-2018', 'Brésil - Serie A', '00:00', 'Sport Recife', 'Internacional', 0.12, 0.24, 3.7, -0.56, -0.11, 0.42, 0.29, 3.0, 0.26, -0.13, 0.46, 0.47, 1.88, -0.14, -0.12, 'N2', 0.0, 0.76, 1.5, 0.14, 0.24, 1.92, -0.54, 'U', 0.0, 2, 1, '1'),
#  (107, '05-10-2018', 'Brésil - Serie A', '02:00', 'Corinthians', 'Flamengo', 0.27, 0.32, 2.73, -0.26, -0.13, 0.52, 0.32, 2.7, 0.4, -0.14, 0.21, 0.36, 2.45, -0.49, -0.12, 'N', 0.0, 0.66, 1.3, -0.14, 0.34, 2.45, -0.17, 'U', 0.0, 0, 3, '2'),
#  (108, '05-10-2018', 'Brésil - Serie A', '02:30', 'Vitoria', 'Santos', 0.43, 0.26, 3.4, 0.46, -0.12, 0.26, 0.3, 2.95, -0.23, -0.11, 0.3, 0.44, 2.0, -0.4, -0.12, None, None, 0.62, 1.44, -0.11, 0.38, 2.05, -0.22, 'U', 1.0, 0, 1, '2'),
#  (109, '05-10-2018', 'Bulgarie - Division 1 - Division 1 Pro', '19:00', 'Cherno More Varna', 'Vereya Stara Zagora', 0.66, 0.74, 1.19, -0.21, -0.12, 0.16, 0.18, 4.9, -0.22, -0.12, 0.19, 0.08, 11.0, 1.09, -0.12, '1', 1.0, 0.63, 1.62, 0.02, 0.37, 1.76, -0.35, 'U', 0.0, 4, 2, '1'),
#  (110, '05-10-2018', 'Croatie - Division 1', '18:00', 'Inter Zapresic', 'Nk Lokomotiva Zagreb', 0.2, 0.21, 4.2, -0.16, -0.12, 0.2, 0.27, 3.25, -0.35, -0.12, 0.6, 0.52, 1.68, 0.01, -0.13, '2', 0.0, 0.26, 1.62, -0.58, 0.74, 1.76, 0.3, 'O', 1.0, 2, 1, '1'),
#  (111, '05-10-2018', 'Danemark - Superligaen', '19:00', 'Sonderjyske', 'Vejle', 0.34, 0.49, 1.8, -0.39, -0.12, 0.44, 0.27, 3.2, 0.41, -0.14, 0.21, 0.24, 3.7, -0.22, -0.11, 'N', 0.0, 0.67, 1.6, 0.07, 0.33, 1.85, -0.39, 'U', 0.0, 3, 0, '1'),
#  (112, '05-10-2018', 'Equateur - Division 1 - Division 1 Stage 2', '03:00', 'Dep. Tecnico Univ.', 'Aucas', 0.13, 0.29, 3.0, -0.61, -0.13, 0.46, 0.29, 3.0, 0.38, -0.13, 0.41, 0.43, 2.02, -0.17, -0.13, 'N2', 0.0, 0.43, 1.6, -0.31, 0.57, 1.78, 0.01, None, None, 3, 0, '1'),
#  (113, '05-10-2018', 'Irlande du Nord - Division 1 - Premiership', '20:45', 'Ards', 'Institute FC', 0.38, 0.36, 2.42, -0.08, -0.13, 0.26, 0.28, 3.1, -0.19, -0.13, 0.36, 0.36, 2.38, -0.14, -0.14, None, None, 0.64, 1.8, 0.15, 0.36, 1.58, -0.43, 'U', 1.0, 0, 1, '2'),
#  (114, '05-10-2018', 'Irlande du Nord - Division 1 - Premiership', '20:45', 'Crusaders FC', 'Cliftonville FC', 0.35, 0.54, 1.61, -0.44, -0.13, 0.29, 0.24, 3.7, 0.07, -0.11, 0.36, 0.22, 4.0, 0.44, -0.12, None, None, 0.3, 2.2, -0.34, 0.7, 1.37, -0.04, 'O', 1.0, 3, 2, '1'),
#  (115, '05-10-2018', 'Italie - Serie B', '21:00', 'Verona', 'Lecce', 0.4, 0.49, 1.82, -0.27, -0.11, 0.31, 0.3, 2.9, -0.1, -0.13, 0.29, 0.21, 4.2, 0.22, -0.12, None, None, 0.37, 1.5, -0.44, 0.63, 1.92, 0.21, 'O', 0.0, 0, 2, '2'),
#  (116, '05-10-2018', 'Japon - J1 League - Première Division', '12:35', 'Yokohama F. Marinos', 'Consadole Sapporo', 0.14, 0.51, 1.72, -0.76, -0.12, 0.5, 0.24, 3.6, 0.8, -0.14, 0.36, 0.25, 3.45, 0.24, -0.14, 'N', 0.0, 0.23, 2.45, -0.44, 0.77, 1.3, 0.0, 'O', 1.0, 2, 1, '1'),
#  (117, '05-10-2018', 'Lituanie - Lyga - Division 1', '15:00', 'Fk Zalgiris Kaunas', 'Palanga', 0.46, 0.43, 2.02, -0.07, -0.13, 0.22, 0.3, 2.85, -0.37, -0.14, 0.32, 0.27, 3.2, 0.02, -0.14, None, None, 0.66, 1.42, -0.06, 0.34, 2.1, -0.29, 'U', 1.0, 2, 0, '1'),
#  (118, '05-10-2018', 'Malte - Division 1', '18:00', 'Pieta Hotspurs', 'Mosta FC', 0.31, 0.27, 3.25, 0.01, -0.12, 0.29, 0.27, 3.25, -0.06, -0.12, 0.4, 0.46, 1.88, -0.25, -0.14, None, None, 0.69, 1.85, 0.28, 0.31, 1.55, -0.52, 'U', 0.0, 3, 1, '1'),
#  (119, '05-10-2018', 'Malte - Division 1', '19:00', 'Valletta FC', 'Balzan FC', 0.39, 0.39, 2.2, -0.14, -0.14, 0.22, 0.28, 3.05, -0.33, -0.15, 0.39, 0.32, 2.68, 0.05, -0.14, None, None, 0.31, 1.73, -0.46, 0.69, 1.66, 0.15, 'O', 1.0, 4, 1, '1'),
#  (120, '05-10-2018', 'Malte - Division 1', '20:15', 'Hamrun Spartans', 'Sliema Wanderers', 0.37, 0.28, 3.15, 0.17, -0.12, 0.22, 0.28, 3.15, -0.31, -0.12, 0.41, 0.45, 1.95, -0.2, -0.12, None, None, 0.85, 1.56, 0.33, 0.16, 1.83, -0.71, 'U', 1.0, 0, 0, 'N'),
#  (121, '05-10-2018', 'Mexique - Liga MX - Apertura', '02:00', 'Santos Laguna', 'Atlas', 0.75, 0.53, 1.66, 0.24, -0.12, 0.19, 0.26, 3.3, -0.37, -0.14, 0.06, 0.21, 4.2, -0.75, -0.12, '1', 1.0, 0.43, 1.7, -0.27, 0.57, 1.7, -0.03, 'O', 1.0, 3, 1, '1'),
#  (122, '05-10-2018', 'Mexique - Liga MX - Apertura', '04:10', 'Veracruz', 'Necaxa', 0.45, 0.29, 3.0, 0.35, -0.13, 0.21, 0.29, 3.05, -0.36, -0.12, 0.34, 0.42, 2.07, -0.3, -0.13, None, None, 0.64, 1.62, 0.04, 0.36, 1.76, -0.37, 'U', 1.0, 0, 0, 'N'),
#  (123, '05-10-2018', 'Paraguay - Division 1  - Clausura', '01:50', 'Sol De America', 'Sportivo Luqueno', 0.44, 0.4, 2.15, -0.05, -0.14, 0.17, 0.29, 2.95, -0.5, -0.14, 0.4, 0.32, 2.7, 0.08, -0.14, None, None, 0.46, 1.62, -0.25, 0.54, 1.76, -0.05, None, None, 1, 0, '1'),
#  (124, '05-10-2018', 'Pays de Galles - Premier League', '20:45', 'Caernarfon Town', 'Bala Town', 0.44, 0.4, 2.1, -0.08, -0.16, 0.26, 0.27, 3.15, -0.18, -0.15, 0.29, 0.33, 2.6, -0.25, -0.14, None, None, 0.65, 1.8, 0.17, 0.35, 1.58, -0.45, 'U', 0.0, 2, 2, 'N'),
#  (125, '05-10-2018', 'Pays de Galles - Premier League', '20:45', 'Cefn Druids Afc', 'Aberystwyth Town', 0.46, 0.49, 1.78, -0.18, -0.13, 0.3, 0.26, 3.35, 0.01, -0.13, 0.24, 0.25, 3.45, -0.17, -0.14, None, None, 0.46, 1.96, -0.1, 0.54, 1.48, -0.2, None, None, 1, 0, '1'),
#  (126, '05-10-2018', 'Pays-Bas - Eredivisie', '20:00', 'Utrecht', 'Nac Breda', 0.62, 0.6, 1.48, -0.08, -0.11, 0.19, 0.23, 3.8, -0.28, -0.13, 0.19, 0.17, 5.1, -0.03, -0.13, '1', 1.0, 0.56, 2.0, 0.12, 0.44, 1.46, -0.36, None, None, 2, 1, '1'),
#  (127, '05-10-2018', 'Pologne - Division 1', '18:00', 'Miedz Legnica', 'Piast Gliwice', 0.31, 0.38, 2.28, -0.29, -0.13, 0.25, 0.29, 3.0, -0.25, -0.13, 0.43, 0.33, 2.65, 0.14, -0.13, None, None, 0.62, 1.7, 0.05, 0.38, 1.7, -0.35, 'U', 0.0, 2, 2, 'N'),
#  (128, '05-10-2018', 'Pologne - Division 1', '20:30', 'Gornik Zabrze', 'Lech Poznan', 0.24, 0.24, 3.6, -0.14, -0.14, 0.34, 0.27, 3.2, 0.09, -0.14, 0.42, 0.48, 1.8, -0.24, -0.14, 'N2', 1.0, 0.65, 1.76, 0.14, 0.35, 1.62, -0.43, 'U', 0.0, 2, 2, 'N'),
#  (129, '05-10-2018', 'Roumanie - Liga I - Ligue 1', '20:00', 'Csms Iasi', 'Viitorul Constanta', 0.48, 0.29, 3.0, 0.44, -0.13, 0.29, 0.31, 2.75, -0.2, -0.15, 0.23, 0.4, 2.15, -0.51, -0.14, None, None, 0.52, 1.42, -0.26, 0.48, 2.1, 0.01, None, None, 1, 2, '2'),
#  (130, '05-10-2018', 'Russie - Premier League', '18:30', 'Arsenal Tula', 'FC Ufa', 0.44, 0.41, 2.1, -0.08, -0.14, 0.33, 0.32, 2.7, -0.11, -0.14, 0.23, 0.27, 3.2, -0.26, -0.14, '1N', 1.0, 0.49, 1.33, -0.35, 0.51, 2.3, 0.17, None, None, 1, 1, 'N'),
#  (131, '05-10-2018', 'Rép. Irlande - Premier League - Premier Division', '20:45', 'Bohemians', 'Waterford United', 0.4, 0.25, 3.6, 0.44, -0.1, 0.14, 0.28, 3.1, -0.57, -0.13, 0.46, 0.47, 1.88, -0.14, -0.12, None, None, 0.31, 1.5, -0.53, 0.69, 1.92, 0.32, 'O', 1.0, 1, 3, '2'),
#  (132, '05-10-2018', 'Rép. Irlande - Premier League - Premier Division', '20:45', 'Dundalk', 'St. Patricks Athletic', 0.92, 0.73, 1.2, 0.1, -0.12, 0.04, 0.17, 5.1, -0.8, -0.13, 0.04, 0.1, 8.5, -0.66, -0.15, '1', 0.0, 0.31, 2.2, -0.32, 0.69, 1.37, -0.05, 'O', 0.0, 1, 1, 'N'),
#  (133, '05-10-2018', 'Rép. Irlande - Premier League - Premier Division', '20:45', 'Limerick FC', 'Derry City', 0.52, 0.37, 2.35, 0.22, -0.13, 0.09, 0.27, 3.2, -0.71, -0.14, 0.39, 0.36, 2.45, -0.04, -0.12, None, None, 0.64, 1.88, 0.2, 0.36, 1.53, -0.45, 'U', 1.0, 0, 1, '2'),
#  (134, '05-10-2018', 'Rép. Irlande - Premier League - Premier Division', '20:45', 'Shamrock Rovers', 'Cork City', 0.41, 0.63, 1.4, -0.43, -0.12, 0.12, 0.25, 3.5, -0.58, -0.12, 0.47, 0.12, 7.5, 2.52, -0.1, None, None, 0.49, 1.44, -0.29, 0.51, 2.05, 0.05, None, None, 0, 0, 'N'),
#  (135, '05-10-2018', 'République Tchèque - Division 1', '18:00', 'FC Fastav Zlin', 'Slovan Liberec', 0.61, 0.42, 2.05, 0.25, -0.14, 0.19, 0.29, 2.95, -0.44, -0.14, 0.21, 0.28, 3.05, -0.36, -0.15, '1', 0.0, 0.35, 1.55, -0.46, 0.65, 1.85, 0.2, 'O', 0.0, 0, 1, '2'),
#  (136, '05-10-2018', 'Serbie - Division 1', '18:00', 'Fk Partizan', 'Fk Vozdovac', 0.62, 0.71, 1.25, -0.22, -0.11, 0.27, 0.19, 4.7, 0.27, -0.11, 0.11, 0.1, 8.5, -0.07, -0.15, '1', 1.0, 0.82, 1.8, 0.48, 0.18, 1.58, -0.72, 'U', 0.0, 4, 0, '1'),
#  (137, '05-10-2018', 'Slovénie - Division 1', '17:30', 'Krsko', 'Rudar Velenje', 0.35, 0.36, 2.38, -0.17, -0.14, 0.31, 0.29, 2.95, -0.09, -0.14, 0.34, 0.34, 2.53, -0.14, -0.14, None, None, 0.67, 1.56, 0.05, 0.33, 1.83, -0.4, 'U', 1.0, 0, 0, 'N'),
#  (138, '05-10-2018', 'Suède - Allsvenskan', '19:00', 'Ostersunds Fk', 'Dalkurd Ff', 0.76, 0.66, 1.35, 0.03, -0.11, 0.05, 0.21, 4.2, -0.79, -0.12, 0.19, 0.13, 6.75, 0.28, -0.12, '1', 1.0, 0.35, 2.05, -0.28, 0.66, 1.44, -0.05, 'O', 1.0, 3, 0, '1'),
#  (139, '05-10-2018', 'Turquie - Super Lig - Super Ligue', '19:00', 'Kasimpasa', 'Goztepe', 0.45, 0.41, 2.1, -0.05, -0.14, 0.22, 0.27, 3.2, -0.3, -0.14, 0.34, 0.32, 2.75, -0.06, -0.12, None, None, 0.33, 1.96, -0.35, 0.67, 1.48, -0.01, 'O', 1.0, 3, 1, '1'),
#  (140, '06-10-2018', 'France - Ligue 1', '17:00', 'Lille', 'St', 0.45, 0.5, 1.96, -0.12, -0.02, 0.3, 0.27, 3.55, 0.06, -0.04, 0.24, 0.23, 4.25, 0.02, -0.02, None, None, 0.28, 1.75, -0.51, 0.72, 1.7, 0.22, 'O', 1.0, 3, 1, '1'),
#  (141, '06-10-2018', 'France - Ligue 1', '20:00', 'Amiens', 'Dijon', 0.3, 0.39, 2.4, -0.28, -0.06, 0.23, 0.3, 3.2, -0.26, -0.04, 0.47, 0.31, 3.05, 0.43, -0.05, None, None, 0.43, 1.6, -0.31, 0.57, 2.0, 0.14, None, None, 1, 0, '1'),
#  (142, '06-10-2018', 'France - Ligue 1', '20:00', 'Angers', 'Strasbourg', 0.32, 0.42, 2.25, -0.28, -0.06, 0.3, 0.3, 3.2, -0.04, -0.04, 0.37, 0.28, 3.35, 0.24, -0.06, None, None, 0.7, 1.53, 0.07, 0.3, 2.1, -0.37, 'U', 0.0, 2, 2, 'N'),
#  (143, '06-10-2018', 'France - Ligue 1', '20:00', 'Guingamp', 'Montpellier', 0.11, 0.31, 3.1, -0.66, -0.04, 0.22, 0.32, 3.0, -0.34, -0.04, 0.67, 0.37, 2.55, 0.71, -0.06, '2', 0.0, 0.62, 1.4, -0.13, 0.38, 2.45, -0.07, 'U', 1.0, 1, 1, 'N'),
#  (144, '06-10-2018', 'France - Ligue 1', '20:00', 'Nîmes', 'Reims', 0.38, 0.38, 2.6, -0.01, -0.01, 0.29, 0.3, 3.25, -0.06, -0.03, 0.33, 0.32, 3.0, -0.01, -0.04, None, None, 0.49, 1.65, -0.19, 0.51, 1.95, -0.01, None, None, 0, 0, 'N'),
#  (145, '06-10-2018', 'France - Ligue 2', '15:00', 'Auxerre', 'Lens', 0.22, 0.34, 2.75, -0.4, -0.06, 0.38, 0.32, 2.95, 0.12, -0.06, 0.4, 0.35, 2.7, 0.08, -0.06, None, None, 0.67, 1.44, -0.04, 0.33, 2.05, -0.32, 'U', 0.0, 1, 2, '2'),
#  (146, '06-10-2018', 'Espagne - Liga Espagnole', '13:00', 'Girona', 'Eibar', 0.38, 0.43, 2.2, -0.16, -0.05, 0.31, 0.3, 3.2, -0.01, -0.04, 0.31, 0.27, 3.5, 0.09, -0.05, None, None, 0.63, 1.44, -0.09, 0.37, 2.05, -0.24, 'U', 0.0, 2, 3, '2'),
#  (147, '06-10-2018', 'Espagne - Liga Espagnole', '16:15', 'Getafe', 'Levante', 0.39, 0.57, 1.65, -0.36, -0.06, 0.26, 0.25, 3.8, -0.01, -0.05, 0.35, 0.18, 5.3, 0.85, -0.05, None, None, 0.78, 1.73, 0.35, 0.22, 1.66, -0.63, 'U', 1.0, 0, 1, '2'),
#  (148, '06-10-2018', 'Espagne - Liga Espagnole', '18:30', 'Alaves', 'Real Madrid', 0.31, 0.1, 10.0, 2.1, 0.0, 0.38, 0.18, 5.25, 1.0, -0.06, 0.31, 0.72, 1.33, -0.59, -0.04, 'N', 0.0, 0.69, 2.2, 0.52, 0.31, 1.37, -0.58, 'U', 1.0, 1, 0, '1'),
#  (149, '06-10-2018', 'Espagne - Liga Espagnole', '20:45', 'Leganes', 'Rayo Vallecano', 0.33, 0.46, 2.05, -0.32, -0.06, 0.33, 0.29, 3.25, 0.07, -0.06, 0.34, 0.25, 3.8, 0.29, -0.05, None, None, 0.52, 1.46, -0.24, 0.48, 2.0, -0.04, None, None, 1, 0, '1'),
#  (150, '06-10-2018', 'Angleterre - Premier League', '16:00', 'Burnley', 'Huddersfield', 0.43, 0.42, 2.2, -0.05, -0.08, 0.25, 0.32, 2.95, -0.26, -0.06, 0.32, 0.26, 3.6, 0.15, -0.06, None, None, 0.5, 1.42, -0.29, 0.5, 2.3, 0.15, None, None, 1, 1, 'N'),
#  (151, '06-10-2018', 'Angleterre - Premier League', '16:00', 'Crystal Palace', 'Wolverhampton', 0.25, 0.33, 2.8, -0.3, -0.08, 0.33, 0.3, 3.1, 0.02, -0.07, 0.42, 0.37, 2.55, 0.07, -0.06, None, None, 0.81, 1.6, 0.3, 0.19, 1.9, -0.64, 'U', 1.0, 0, 1, '2'),
#  (152, '06-10-2018', 'Angleterre - Premier League', '16:00', 'Leicester', 'Everton', 0.42, 0.45, 2.1, -0.12, -0.05, 0.32, 0.28, 3.3, 0.06, -0.08, 0.26, 0.27, 3.45, -0.1, -0.07, '1N', 0.0, 0.38, 1.67, -0.37, 0.62, 1.8, 0.12, 'O', 1.0, 1, 2, '2'),
#  (153, '06-10-2018', 'Angleterre - Premier League', '16:00', 'Tottenham', 'Cardiff', 0.58, 0.79, 1.19, -0.31, -0.06, 0.2, 0.14, 6.85, 0.37, -0.04, 0.21, 0.07, 13.0, 1.73, -0.09, '1', 1.0, 0.38, 2.3, -0.13, 0.62, 1.4, -0.13, 'O', 0.0, 1, 0, '1'),
#  (154, '06-10-2018', 'Angleterre - Premier League', '16:00', 'Watford', 'Bournemouth', 0.45, 0.47, 2.0, -0.1, -0.06, 0.21, 0.27, 3.5, -0.26, -0.05, 0.34, 0.26, 3.6, 0.22, -0.06, None, None, 0.46, 1.8, -0.17, 0.54, 1.67, -0.1, None, None, 0, 4, '2'),
#  (155, '06-10-2018', 'Angleterre - Premier League', '18:30', 'Manchester Utd', 'Newcastle', 0.33, 0.69, 1.36, -0.55, -0.06, 0.39, 0.2, 4.7, 0.83, -0.06, 0.27, 0.1, 9.0, 1.43, -0.1, 'N', 0.0, 0.65, 1.8, 0.17, 0.35, 1.67, -0.42, 'U', 0.0, 3, 2, '1'),
#  (156, '06-10-2018', 'Italie - Serie A', '15:00', 'Cagliari', 'Bologna', 0.37, 0.43, 2.15, -0.2, -0.08, 0.42, 0.3, 3.1, 0.3, -0.07, 0.21, 0.27, 3.5, -0.26, -0.05, 'N', 0.0, 0.68, 1.5, 0.02, 0.32, 2.1, -0.33, 'U', 1.0, 2, 0, '1'),
#  (157, '06-10-2018', 'Italie - Serie A', '18:00', 'Udinese', 'Juventus', 0.27, 0.09, 11.0, 1.97, -0.01, 0.36, 0.19, 5.0, 0.8, -0.05, 0.37, 0.73, 1.3, -0.52, -0.05, None, None, 0.55, 1.75, -0.04, 0.45, 1.72, -0.23, None, None, 0, 2, '2'),
#  (158, '06-10-2018', 'Italie - Serie A', '20:30', 'Empoli', 'Roma', 0.39, 0.19, 5.0, 0.95, -0.05, 0.27, 0.24, 4.0, 0.08, -0.04, 0.34, 0.57, 1.67, -0.43, -0.05, None, None, 0.7, 2.2, 0.54, 0.3, 1.44, -0.57, 'U', 1.0, 0, 2, '2'),
#  (159, '06-10-2018', 'Allemagne - Bundesliga', '15:30', 'Borussia Dortmund', 'FC Augsburg', 0.64, 0.65, 1.5, -0.04, -0.02, 0.18, 0.21, 4.6, -0.17, -0.03, 0.18, 0.14, 6.75, 0.21, -0.05, '1', 1.0, 0.3, 2.25, -0.32, 0.7, 1.42, -0.01, 'O', 1.0, 4, 3, '1'),
#  (160, '06-10-2018', 'Allemagne - Bundesliga', '15:30', 'Fortuna Dusseldorf', 'FC Schalke 04', 0.46, 0.25, 3.7, 0.7, -0.07, 0.23, 0.27, 3.4, -0.22, -0.08, 0.31, 0.47, 1.97, -0.39, -0.07, None, None, 0.49, 1.75, -0.14, 0.51, 1.72, -0.12, None, None, 0, 2, '2'),
#  (161, '06-10-2018', 'Allemagne - Bundesliga', '15:30', 'Fsv Mainz 05', 'Hertha Berlin', 0.38, 0.36, 2.6, -0.01, -0.06, 0.33, 0.29, 3.25, 0.07, -0.06, 0.29, 0.36, 2.6, -0.25, -0.06, None, None, 0.75, 1.6, 0.2, 0.25, 1.9, -0.52, 'U', 1.0, 0, 0, 'N'),
#  (162, '06-10-2018', 'Allemagne - Bundesliga', '15:30', 'Hannover 96', 'VFB Stuttgart', 0.37, 0.4, 2.35, -0.13, -0.06, 0.35, 0.28, 3.35, 0.17, -0.06, 0.28, 0.32, 2.9, -0.19, -0.07, '1N', 1.0, 0.73, 1.78, 0.3, 0.28, 1.7, -0.52, 'U', 0.0, 3, 1, '1'),
#  (163, '06-10-2018', 'Allemagne - Bundesliga', '18:30', 'Bayern Munich', 'Borussia Monchengladbach', 0.43, 0.82, 1.16, -0.5, -0.05, 0.38, 0.12, 8.0, 2.04, -0.04, 0.18, 0.06, 16.0, 1.88, -0.04, '1N', 0.0, 0.36, 3.4, 0.22, 0.64, 1.17, -0.25, 'O', 1.0, 0, 3, '2'),
#  (164, '06-10-2018', 'Portugal - Primeira Liga', '16:30', 'Vitoria Setubal', 'Moreirense', 0.39, 0.44, 2.05, -0.2, -0.1, 0.21, 0.3, 3.0, -0.37, -0.1, 0.41, 0.26, 3.5, 0.43, -0.09, None, None, 0.67, 1.42, -0.05, 0.33, 2.1, -0.31, 'U', 0.0, 3, 0, '1'),
#  (165, '06-10-2018', 'Portugal - Primeira Liga', '19:00', 'Maritimo', 'Guimaraes', 0.45, 0.41, 2.2, -0.01, -0.1, 0.28, 0.3, 2.95, -0.17, -0.11, 0.27, 0.29, 3.05, -0.18, -0.12, None, None, 0.75, 1.48, 0.11, 0.25, 1.96, -0.51, 'U', 0.0, 1, 3, '2'),
#  (166, '06-10-2018', 'Portugal - Primeira Liga', '21:30', 'SC Braga', 'Rio Ave', 0.48, 0.69, 1.33, -0.36, -0.08, 0.25, 0.2, 4.6, 0.15, -0.08, 0.27, 0.11, 8.0, 1.16, -0.12, None, None, 0.35, 2.0, -0.3, 0.65, 1.46, -0.05, 'O', 0.0, 1, 1, 'N'),
#  (167, '06-10-2018', 'Allemagne - Bundesliga 2', '13:00', 'Erzgebirge Aue', 'Holstein Kiel', 0.38, 0.31, 2.75, 0.05, -0.15, 0.29, 0.29, 3.0, -0.13, -0.13, 0.33, 0.4, 2.18, -0.28, -0.13, None, None, 0.68, 1.62, 0.1, 0.32, 1.78, -0.43, 'U', 0.0, 2, 1, '1'),
#  (168, '06-10-2018', 'Allemagne - Bundesliga 2', '13:00', 'FC Magdeburg', 'Dynamo Dresden', 0.2, 0.37, 2.38, -0.52, -0.12, 0.36, 0.3, 2.95, 0.06, -0.11, 0.45, 0.34, 2.6, 0.17, -0.12, 'N2', 1.0, 0.62, 1.58, -0.02, 0.38, 1.8, -0.32, 'U', 0.0, 2, 2, 'N'),
#  (169, '06-10-2018', 'Allemagne - Bundesliga 2', '13:00', 'SpVgg Greuther Fürth', 'Jahn Regensburg', 0.4, 0.38, 2.3, -0.08, -0.13, 0.26, 0.27, 3.25, -0.16, -0.12, 0.34, 0.35, 2.5, -0.15, -0.13, None, None, 0.45, 1.96, -0.12, 0.55, 1.48, -0.19, None, None, 1, 1, 'N'),
#  (170, '06-10-2018', 'Angleterre - Championship', '13:30', 'Leeds', 'Brentford', 0.45, 0.45, 2.0, -0.1, -0.1, 0.39, 0.27, 3.3, 0.29, -0.11, 0.16, 0.28, 3.15, -0.5, -0.12, '1N', 1.0, 0.35, 1.91, -0.33, 0.65, 1.55, 0.01, 'O', 0.0, 1, 1, 'N'),
#  (171, '06-10-2018', 'Angleterre - Championship', '16:00', 'Birmingham', 'Rotherham', 0.45, 0.56, 1.57, -0.29, -0.12, 0.42, 0.26, 3.4, 0.43, -0.12, 0.13, 0.18, 5.0, -0.35, -0.1, '1N', 1.0, 0.68, 1.6, 0.09, 0.32, 1.83, -0.41, 'U', 0.0, 3, 1, '1'),
#  (172, '06-10-2018', 'Angleterre - Championship', '16:00', 'Middlesbrough', 'Nottingham', 0.49, 0.53, 1.65, -0.19, -0.13, 0.41, 0.28, 3.15, 0.29, -0.12, 0.1, 0.19, 4.5, -0.55, -0.15, '1N', 0.0, 0.84, 1.5, 0.26, 0.16, 2.05, -0.67, 'U', 1.0, 0, 2, '2'),
#  (173, '06-10-2018', 'Angleterre - Championship', '16:00', 'Millwall', 'Aston Villa', 0.19, 0.35, 2.5, -0.52, -0.13, 0.42, 0.29, 2.95, 0.24, -0.14, 0.39, 0.36, 2.42, -0.06, -0.13, 'N2', 0.0, 0.44, 1.65, -0.27, 0.56, 1.83, 0.02, None, None, 2, 1, '1'),
#  (174, '06-10-2018', 'Angleterre - Championship', '16:00', 'Norwich', 'Stoke City', 0.43, 0.37, 2.33, 0.0, -0.14, 0.33, 0.3, 2.95, -0.03, -0.11, 0.24, 0.33, 2.65, -0.36, -0.13, '1N', 0.0, 0.51, 1.65, -0.16, 0.49, 1.8, -0.12, None, None, 0, 1, '2'),
#  (175, '06-10-2018', 'Angleterre - Championship', '16:00', 'Preston', 'Wigan', 0.41, 0.41, 2.15, -0.12, -0.12, 0.28, 0.28, 3.1, -0.13, -0.13, 0.31, 0.31, 2.8, -0.13, -0.13, None, None, 0.43, 1.73, -0.26, 0.57, 1.7, -0.03, None, None, 4, 0, '1'),
#  (176, '06-10-2018', 'Angleterre - Championship', '16:00', 'Queens Park Rangers', 'Derby', 0.38, 0.34, 2.6, -0.01, -0.12, 0.17, 0.3, 2.95, -0.5, -0.11, 0.44, 0.36, 2.45, 0.08, -0.12, None, None, 0.73, 1.65, 0.2, 0.27, 1.8, -0.51, 'U', 1.0, 1, 1, 'N'),
#  (177, '06-10-2018', 'Angleterre - Championship', '16:00', 'Sheffield Utd', 'Hull City', 0.61, 0.6, 1.45, -0.12, -0.13, 0.2, 0.24, 3.6, -0.28, -0.14, 0.19, 0.16, 5.5, 0.04, -0.12, '1', 1.0, 0.31, 1.83, -0.43, 0.69, 1.65, 0.14, 'O', 0.0, 1, 0, '1'),
#  (178, '06-10-2018', 'Angleterre - Championship', '16:00', 'Swansea', 'Ipswich', 0.63, 0.5, 1.76, 0.11, -0.12, 0.24, 0.29, 3.05, -0.27, -0.12, 0.13, 0.2, 4.33, -0.44, -0.13, '1', 0.0, 0.69, 1.5, 0.03, 0.31, 2.1, -0.35, 'U', 0.0, 2, 3, '2'),
#  (179, '06-10-2018', 'Angleterre - Championship', '16:00', 'West Brom', 'Reading', 0.58, 0.61, 1.45, -0.16, -0.12, 0.24, 0.23, 3.8, -0.09, -0.13, 0.18, 0.16, 5.7, 0.03, -0.09, '1', 1.0, 0.28, 1.92, -0.46, 0.72, 1.55, 0.12, 'O', 1.0, 4, 1, '1'),
#  (180, '06-10-2018', 'Angleterre - Championship', '18:30', 'Bolton', 'Blackburn', 0.25, 0.28, 3.1, -0.22, -0.13, 0.33, 0.3, 2.9, -0.04, -0.13, 0.43, 0.42, 2.1, -0.1, -0.12, None, None, 0.65, 1.53, -0.01, 0.35, 1.96, -0.31, 'U', 1.0, 0, 1, '2'),
#  (181, '06-10-2018', 'Argentine - Primera Division - Superligue Argentine', '18:15', 'Aldosivi', 'San Martin Tucuman', 0.63, 0.43, 2.05, 0.29, -0.12, 0.18, 0.32, 2.75, -0.51, -0.12, 0.19, 0.26, 3.4, -0.35, -0.12, '1', 1.0, 0.65, 1.32, -0.14, 0.35, 2.35, -0.18, 'U', 1.0, 2, 0, '1'),
#  (182, '06-10-2018', 'Argentine - Primera Division - Superligue Argentine', '20:30', 'Gimnasia L.P.', 'Godoy Cruz', 0.4, 0.43, 2.02, -0.19, -0.13, 0.34, 0.32, 2.7, -0.08, -0.14, 0.26, 0.24, 3.6, -0.06, -0.14, None, None, 0.77, 1.3, 0.0, 0.23, 2.45, -0.44, 'U', 1.0, 1, 0, '1'),
#  (183, '06-10-2018', 'Argentine - Primera Division - Superligue Argentine', '22:45', 'San Martin S.J.', 'Velez Sarsfield', 0.41, 0.26, 3.3, 0.35, -0.14, 0.27, 0.31, 2.8, -0.24, -0.13, 0.33, 0.42, 2.05, -0.32, -0.14, None, None, 0.65, 1.35, -0.12, 0.35, 2.25, -0.21, 'U', 0.0, 3, 1, '1'),
#  (184, '06-10-2018', 'Argentine - Primera Division - Superligue Argentine', '01:00', 'Patronato', 'Independiente', 0.24, 0.21, 4.3, 0.03, -0.1, 0.42, 0.3, 2.9, 0.22, -0.13, 0.34, 0.49, 1.8, -0.39, -0.12, 'N', 0.0, 0.68, 1.3, -0.12, 0.33, 2.45, -0.19, 'U', 0.0, 1, 2, '2'),
#  (185, '06-10-2018', 'Autriche - Bundesliga', '17:00', 'Scr Altach', 'Austria Vienne', 0.27, 0.29, 3.0, -0.19, -0.13, 0.31, 0.28, 3.15, -0.02, -0.12, 0.42, 0.43, 2.05, -0.14, -0.12, None, None, 0.61, 1.78, 0.09, 0.39, 1.6, -0.38, 'U', 1.0, 2, 0, '1'),
#  (186, '06-10-2018', 'Autriche - Bundesliga', '17:00', 'Skn St. Polten', 'Admira Wacker', 0.57, 0.52, 1.69, -0.04, -0.12, 0.15, 0.25, 3.45, -0.48, -0.14, 0.28, 0.23, 3.8, 0.06, -0.13, '1', 0.0, 0.35, 1.92, -0.33, 0.65, 1.5, -0.02, 'O', 0.0, 0, 0, 'N'),
#  (187, '06-10-2018', 'Autriche - Bundesliga', '17:00', 'Wolfsberger AC', 'Tsv Hartberg', 0.68, 0.54, 1.61, 0.09, -0.13, 0.16, 0.25, 3.45, -0.45, -0.14, 0.16, 0.21, 4.1, -0.34, -0.14, '1', 0.0, 0.38, 1.83, -0.3, 0.62, 1.56, -0.03, 'O', 1.0, 3, 4, '2'),
#  (188, '06-10-2018', 'Belgique - Division 1', '18:00', 'AS Eupen', 'Antwerp', 0.3, 0.26, 3.4, 0.02, -0.12, 0.34, 0.28, 3.15, 0.07, -0.12, 0.36, 0.47, 1.86, -0.33, -0.13, None, None, 0.59, 1.66, -0.02, 0.42, 1.73, -0.27, 'U', 0.0, 1, 2, '2'),
#  (189, '06-10-2018', 'Belgique - Division 1', '20:00', 'Lokeren', 'FC Courtrai', 0.28, 0.32, 2.75, -0.23, -0.12, 0.26, 0.27, 3.3, -0.14, -0.11, 0.46, 0.41, 2.12, -0.02, -0.13, None, None, 0.69, 1.88, 0.3, 0.31, 1.53, -0.53, 'U', 0.0, 1, 3, '2'),
# ...
#  (937, '21-10-2018', 'Brésil - Serie A', '21:00', 'Fluminense', 'Atletico Mineiro', 0.42, 0.36, 2.41, 0.01, -0.13, 0.3, 0.3, 2.9, -0.13, -0.13, 0.28, 0.34, 2.59, -0.27, -0.12, None, None, 0.73, 1.53, 0.12, 0.27, 1.88, -0.49, 'U', 1.0, 1, 0, '1'),
#  (938, '21-10-2018', 'Brésil - Serie A', '21:00', 'Palmeiras', 'Ceara', 0.82, 0.66, 1.35, 0.11, -0.11, 0.13, 0.22, 4.0, -0.48, -0.12, 0.05, 0.11, 8.0, -0.6, -0.12, '1', 1.0, 0.65, 1.53, -0.01, 0.35, 1.88, -0.34, 'U', 0.0, 2, 1, '1'),
#  (939, '21-10-2018', 'Brésil - Serie A', '21:00', 'Vitoria', 'Corinthians', 0.49, 0.39, 2.25, 0.1, -0.12, 0.22, 0.32, 2.75, -0.4, -0.12, 0.3, 0.29, 3.1, -0.07, -0.1, None, None, 0.63, 1.35, -0.15, 0.37, 2.25, -0.17, 'U', 0.0, 2, 2, 'N'),
#  (940, '21-10-2018', 'Brésil - Serie A', '00:00', 'Cruzeiro', 'Chapecoense', 0.48, 0.57, 1.57, -0.25, -0.11, 0.41, 0.27, 3.3, 0.35, -0.11, 0.11, 0.16, 5.7, -0.37, -0.09, '1N', 1.0, 0.71, 1.37, -0.03, 0.29, 2.2, -0.36, 'U', 0.0, 3, 0, '1'),
#  (941, '21-10-2018', 'Brésil - Serie A', '00:00', 'Parana', 'Flamengo', 0.15, 0.13, 7.05, 0.06, -0.08, 0.46, 0.24, 3.6, 0.66, -0.14, 0.39, 0.63, 1.4, -0.45, -0.12, 'N', 0.0, 0.68, 1.42, -0.03, 0.32, 2.1, -0.33, 'U', 0.0, 0, 4, '2'),
#  (942, '21-10-2018', 'Bulgarie - Division 1 - Division 1 Pro', '16:30', 'Dunav Ruse', 'Lokomotiv Plovdiv', 0.23, 0.37, 2.33, -0.46, -0.14, 0.2, 0.32, 2.75, -0.45, -0.12, 0.58, 0.31, 2.78, 0.61, -0.14, '2', 0.0, 0.47, 1.42, -0.33, 0.53, 2.1, 0.11, None, None, 1, 0, '1'),
#  (943, '21-10-2018', 'Bulgarie - Division 1 - Division 1 Pro', '19:00', 'Pfk Cska', 'Etar Veliko Tarnovo', 0.67, 0.74, 1.2, -0.2, -0.11, 0.11, 0.17, 5.3, -0.42, -0.1, 0.22, 0.09, 9.75, 1.14, -0.12, '1', 1.0, 0.33, 1.73, -0.43, 0.67, 1.66, 0.11, 'O', 1.0, 3, 0, '1'),
#  (944, '21-10-2018', 'Chili - Primera Division', '01:00', 'Universidad Catolica', 'Universidad De Concepcion', 0.45, 0.46, 1.87, -0.16, -0.14, 0.24, 0.28, 3.05, -0.27, -0.15, 0.31, 0.25, 3.47, 0.08, -0.13, None, None, 0.59, 1.56, -0.08, 0.41, 1.83, -0.25, 'U', 1.0, 1, 0, '1'),
#  (945, '21-10-2018', 'Chili - Primera Division', '17:00', 'Iquique', 'San Luis', 0.48, 0.53, 1.65, -0.21, -0.13, 0.25, 0.27, 3.3, -0.18, -0.11, 0.27, 0.2, 4.3, 0.16, -0.14, None, None, 0.61, 1.73, 0.06, 0.39, 1.66, -0.35, 'U', 0.0, 2, 2, 'N'),
#  (946, '21-10-2018', 'Chili - Primera Division', '20:00', 'Antofagasta', 'Audax Italiano', 0.79, 0.47, 1.83, 0.45, -0.14, 0.12, 0.28, 3.05, -0.63, -0.15, 0.09, 0.24, 3.6, -0.68, -0.14, '1', 0.0, 0.65, 1.56, 0.01, 0.35, 1.83, -0.36, 'U', 1.0, 1, 1, 'N'),
#  (947, '21-10-2018', 'Chili - Primera Division', '01:00', 'Universidad De Chile', 'Everton De Vina', 0.71, 0.41, 2.13, 0.51, -0.13, 0.09, 0.29, 3.0, -0.73, -0.13, 0.2, 0.3, 2.85, -0.43, -0.14, '1', 1.0, 0.49, 1.7, -0.17, 0.51, 1.7, -0.13, None, None, 2, 0, '1'),
#  (948, '21-10-2018', 'Chypre - Division 1', '16:00', 'Nea Salamis', 'Omonia', 0.4, 0.24, 3.65, 0.46, -0.12, 0.29, 0.26, 3.35, -0.03, -0.13, 0.31, 0.5, 1.72, -0.47, -0.14, None, None, 0.5, 1.85, -0.07, 0.5, 1.55, -0.22, None, None, 1, 0, '1'),
#  (949, '21-10-2018', 'Chypre - Division 1', '18:00', 'Apoel', 'Ael Limassol', 0.16, 0.54, 1.62, -0.74, -0.13, 0.18, 0.26, 3.3, -0.41, -0.14, 0.66, 0.2, 4.3, 1.84, -0.14, '2', 0.0, 0.5, 1.56, -0.22, 0.5, 1.83, -0.08, None, None, 0, 0, 'N'),
#  (950, '21-10-2018', 'Croatie - Division 1', '15:00', 'Nk Slaven Belupo', 'Hnk Gorica', 0.26, 0.46, 1.9, -0.51, -0.13, 0.25, 0.3, 2.9, -0.28, -0.13, 0.49, 0.24, 3.6, 0.76, -0.14, None, None, 0.58, 1.46, -0.15, 0.42, 2.0, -0.16, 'U', 1.0, 0, 1, '2'),
#  (951, '21-10-2018', 'Croatie - Division 1', '17:30', 'Nk Lokomotiva Zagreb', 'Hnk Hajduk Split', 0.59, 0.35, 2.45, 0.45, -0.14, 0.25, 0.3, 2.9, -0.28, -0.13, 0.16, 0.35, 2.45, -0.61, -0.14, '1', 1.0, 0.54, 1.58, -0.15, 0.46, 1.8, -0.17, None, None, 2, 0, '1'),
#  (952, '21-10-2018', 'Danemark - Superligaen', '12:00', 'Vendsyssel Ff', 'AC Horsens', 0.25, 0.35, 2.48, -0.38, -0.13, 0.19, 0.3, 2.95, -0.44, -0.11, 0.55, 0.35, 2.47, 0.36, -0.14, '2', 1.0, 0.51, 1.62, -0.17, 0.49, 1.8, -0.12, None, None, 0, 1, '2'),
#  (953, '21-10-2018', 'Danemark - Superligaen', '14:00', 'Randers FC', 'Sonderjyske', 0.45, 0.4, 2.15, -0.03, -0.14, 0.31, 0.29, 3.0, -0.07, -0.13, 0.25, 0.31, 2.8, -0.3, -0.13, None, None, 0.52, 1.67, -0.13, 0.48, 1.76, -0.16, None, None, 1, 1, 'N'),
#  (954, '21-10-2018', 'Danemark - Superligaen', '16:00', 'Vejle', 'FC Copenhagen', 0.19, 0.15, 6.0, 0.14, -0.1, 0.24, 0.24, 3.7, -0.11, -0.11, 0.58, 0.62, 1.42, -0.18, -0.12, '2', 1.0, 0.64, 1.85, 0.18, 0.36, 1.67, -0.4, 'U', 0.0, 1, 3, '2'),
#  (955, '21-10-2018', 'Danemark - Superligaen', '18:00', 'Aarhus', 'Aalborg', 0.2, 0.4, 2.2, -0.56, -0.12, 0.41, 0.29, 2.96, 0.21, -0.14, 0.39, 0.31, 2.8, 0.09, -0.13, 'N2', 1.0, 0.54, 1.62, -0.13, 0.47, 1.8, -0.15, None, None, 2, 2, 'N'),
#  (956, '21-10-2018', 'Ecosse - Premiership', '14:30', 'Hamilton Academical', 'Rangers', 0.35, 0.09, 9.5, 2.32, -0.15, 0.3, 0.17, 5.1, 0.53, -0.13, 0.35, 0.73, 1.22, -0.57, -0.11, None, None, 0.46, 2.0, -0.08, 0.54, 1.5, -0.19, None, None, 1, 4, '2'),
#  (957, '21-10-2018', 'Equateur - Division 1 - Division 1 Stage 2', '01:10', 'Ldu Quito', 'Deportivo Cuenca', 0.8, 0.58, 1.52, 0.22, -0.12, 0.15, 0.26, 3.35, -0.5, -0.13, 0.06, 0.16, 5.6, -0.66, -0.1, '1', 1.0, 0.81, 1.5, 0.22, 0.19, 1.92, -0.64, 'U', 1.0, 1, 0, '1'),
#  (958, '21-10-2018', 'Equateur - Division 1 - Division 1 Stage 2', '03:15', 'Delfin SC', 'Aucas', 0.46, 0.51, 1.7, -0.22, -0.13, 0.42, 0.28, 3.13, 0.31, -0.12, 0.12, 0.21, 4.1, -0.51, -0.14, '1N', 1.0, 0.51, 1.56, -0.2, 0.49, 1.83, -0.1, None, None, 1, 0, '1'),
#  (959, '21-10-2018', 'Equateur - Division 1 - Division 1 Stage 2', '23:30', 'Emelec', 'Macara', 0.49, 0.49, 1.8, -0.12, -0.12, 0.36, 0.3, 2.9, 0.04, -0.13, 0.15, 0.21, 4.1, -0.39, -0.14, None, None, 0.59, 1.37, -0.19, 0.41, 2.2, -0.1, 'U', 0.0, 3, 1, '1'),
#  (960, '21-10-2018', 'Espagne - Segunda Division', '12:00', 'Mallorca', 'Extremadura', 0.59, 0.56, 1.55, -0.09, -0.13, 0.17, 0.26, 3.35, -0.43, -0.13, 0.23, 0.17, 5.0, 0.15, -0.15, '1', 0.0, 0.5, 1.62, -0.19, 0.5, 1.76, -0.12, None, None, 1, 1, 'N'),
#  (961, '21-10-2018', 'Espagne - Segunda Division', '16:00', 'Lugo', 'Gimnastic', 0.35, 0.51, 1.72, -0.4, -0.12, 0.35, 0.28, 3.1, 0.08, -0.13, 0.3, 0.21, 4.23, 0.27, -0.11, '1N', 1.0, 0.62, 1.46, -0.09, 0.38, 2.0, -0.24, 'U', 1.0, 1, 0, '1'),
#  (962, '21-10-2018', 'Espagne - Segunda Division', '18:00', 'Albacete', 'Almeria', 0.4, 0.39, 2.25, -0.1, -0.12, 0.35, 0.32, 2.75, -0.04, -0.12, 0.25, 0.29, 3.0, -0.25, -0.13, '1N', 1.0, 0.49, 1.37, -0.33, 0.51, 2.2, 0.12, None, None, 1, 1, 'N'),
#  (963, '21-10-2018', 'Espagne - Segunda Division', '18:00', 'Reus', 'Rayo Majadahonda', 0.34, 0.39, 2.26, -0.23, -0.12, 0.3, 0.33, 2.65, -0.2, -0.13, 0.35, 0.29, 3.05, 0.07, -0.12, None, None, 0.66, 1.3, -0.14, 0.34, 2.45, -0.17, 'U', 0.0, 2, 1, '1'),
#  (964, '21-10-2018', 'Espagne - Segunda Division', '20:00', 'Saragosse', 'Tenerife', 0.35, 0.41, 2.15, -0.25, -0.12, 0.43, 0.3, 2.9, 0.25, -0.13, 0.22, 0.28, 3.1, -0.32, -0.13, 'N', 1.0, 0.65, 1.53, -0.01, 0.35, 1.88, -0.34, 'U', 1.0, 1, 1, 'N'),
#  (965, '21-10-2018', 'Espagne - Segunda Division', '20:30', 'Cadiz', 'Sporting Gijon', 0.41, 0.39, 2.25, -0.08, -0.12, 0.37, 0.33, 2.7, 0.0, -0.11, 0.22, 0.28, 3.1, -0.32, -0.13, '1N', 1.0, 0.69, 1.35, -0.07, 0.31, 2.25, -0.3, 'U', 1.0, 0, 0, 'N'),
#  (966, '21-10-2018', 'Estonie - Division 1', '12:00', 'Fci Levadia', 'Tulevik Viljandi', 0.93, 0.94, 1.01, -0.06, -0.05, 0.04, 0.04, 22.0, -0.12, -0.12, 0.04, 0.02, 60.0, 1.4, 0.2, '1', 1.0, 0.29, 4.5, 0.3, 0.71, 1.04, -0.26, 'O', 1.0, 2, 1, '1'),
#  (967, '21-10-2018', 'Estonie - Division 1', '14:00', 'Kalju Nomme', 'Tammeka Tartu', 0.91, 0.76, 1.16, 0.06, -0.12, 0.04, 0.16, 5.7, -0.77, -0.09, 0.05, 0.08, 11.0, -0.45, -0.12, '1', 0.0, 0.26, 2.2, -0.43, 0.74, 1.37, 0.01, 'O', 1.0, 2, 2, 'N'),
#  (968, '21-10-2018', 'Etats-Unis - Major League Soccer', '21:15', 'Atlanta United FC', 'Chicago Fire', 0.83, 0.75, 1.21, 0.0, -0.09, 0.12, 0.15, 5.9, -0.29, -0.12, 0.05, 0.09, 10.0, -0.5, -0.1, '1', 1.0, 0.29, 2.85, -0.17, 0.71, 1.2, -0.15, 'O', 1.0, 2, 1, '1'),
#  (969, '21-10-2018', 'Etats-Unis - Major League Soccer', '21:15', 'Dc United', 'New York City FC', 0.55, 0.41, 2.15, 0.18, -0.12, 0.28, 0.26, 3.3, -0.08, -0.14, 0.17, 0.33, 2.65, -0.55, -0.13, None, None, 0.46, 2.2, 0.01, 0.54, 1.37, -0.26, None, None, 3, 1, '1'),
#  (970, '21-10-2018', 'Etats-Unis - Major League Soccer', '21:15', 'Montreal Impact', 'Toronto FC', 0.85, 0.54, 1.66, 0.41, -0.1, 0.09, 0.24, 3.7, -0.67, -0.11, 0.06, 0.22, 4.0, -0.76, -0.12, '1', 1.0, 0.63, 2.3, 0.45, 0.37, 1.33, -0.51, 'U', 1.0, 2, 0, '1'),
#  (971, '21-10-2018', 'Etats-Unis - Major League Soccer', '21:15', 'Orlando City', 'Columbus Crew', 0.25, 0.23, 3.9, -0.03, -0.1, 0.32, 0.23, 3.8, 0.22, -0.13, 0.44, 0.54, 1.64, -0.28, -0.11, None, None, 0.44, 2.2, -0.03, 0.56, 1.37, -0.23, None, None, 2, 1, '1'),
#  (972, '21-10-2018', 'Etats-Unis - Major League Soccer', '21:15', 'Philadelphia Union', 'New York Red Bulls', 0.34, 0.37, 2.35, -0.2, -0.13, 0.25, 0.27, 3.3, -0.18, -0.11, 0.41, 0.36, 2.45, 0.0, -0.12, None, None, 0.48, 2.1, 0.01, 0.52, 1.42, -0.26, None, None, 0, 1, '2'),
#  (973, '21-10-2018', 'Etats-Unis - Major League Soccer', '23:25', 'FC Dallas', 'Sporting Kansas City', 0.41, 0.42, 2.08, -0.15, -0.13, 0.25, 0.27, 3.25, -0.19, -0.12, 0.33, 0.31, 2.8, -0.08, -0.13, None, None, 0.48, 1.88, -0.1, 0.52, 1.53, -0.2, None, None, 0, 3, '2'),
#  (974, '21-10-2018', 'Etats-Unis - Major League Soccer', '23:25', 'Houston Dynamo', 'Seattle Sounders', 0.25, 0.36, 2.4, -0.4, -0.14, 0.13, 0.26, 3.4, -0.56, -0.12, 0.63, 0.38, 2.3, 0.45, -0.13, '2', 1.0, 0.45, 2.2, -0.01, 0.55, 1.37, -0.25, None, None, 2, 3, '2'),
#  (975, '21-10-2018', 'Etats-Unis - Major League Soccer', '23:25', 'Los Angeles FC', 'Vancouver Whitecaps', 0.67, 0.72, 1.24, -0.17, -0.11, 0.2, 0.17, 5.4, 0.08, -0.08, 0.14, 0.11, 8.0, 0.12, -0.12, '1', 0.0, 0.42, 2.85, 0.2, 0.58, 1.2, -0.3, 'O', 1.0, 2, 2, 'N'),
#  (976, '21-10-2018', 'Etats-Unis - Major League Soccer', '23:25', 'Minnesota United FC', 'Los Angeles Galaxy', 0.5, 0.3, 2.9, 0.45, -0.13, 0.21, 0.24, 3.7, -0.22, -0.11, 0.29, 0.46, 1.9, -0.45, -0.13, None, None, 0.28, 2.75, -0.23, 0.72, 1.22, -0.12, 'O', 1.0, 1, 3, '2'),
#  (977, '21-10-2018', 'Etats-Unis - Major League Soccer', '23:25', 'Portland Timbers', 'Real Salt Lake', 0.54, 0.55, 1.6, -0.14, -0.12, 0.3, 0.23, 3.9, 0.17, -0.1, 0.16, 0.23, 3.9, -0.38, -0.1, None, None, 0.52, 2.45, 0.27, 0.48, 1.3, -0.38, None, None, 3, 0, '1'),
#  (978, '21-10-2018', 'Etats-Unis - Major League Soccer', '23:25', 'San Jose Earthquakes', 'Colorado Rapids', 0.38, 0.5, 1.76, -0.33, -0.12, 0.2, 0.25, 3.6, -0.28, -0.1, 0.42, 0.25, 3.5, 0.47, -0.12, None, None, 0.23, 2.3, -0.47, 0.77, 1.33, 0.02, 'O', 0.0, 0, 0, 'N'),
#  (979, '21-10-2018', 'Finlande - Division 1', '13:30', 'Hjk Helsinki', 'Seinäjoen JK', 0.86, 0.62, 1.42, 0.22, -0.12, 0.09, 0.24, 3.6, -0.68, -0.14, 0.05, 0.14, 6.25, -0.69, -0.12, '1', 1.0, 0.5, 1.66, -0.17, 0.5, 1.73, -0.14, None, None, 1, 0, '1'),
#  (980, '21-10-2018', 'Finlande - Division 1', '13:30', 'Ilves', 'FC Lahti', 0.34, 0.56, 1.55, -0.47, -0.13, 0.49, 0.26, 3.35, 0.64, -0.13, 0.17, 0.18, 4.8, -0.18, -0.14, 'N', 0.0, 0.62, 1.6, -0.01, 0.38, 1.78, -0.32, 'U', 1.0, 0, 1, '2'),
#  (981, '21-10-2018', 'Finlande - Division 1', '13:30', 'Kups', 'Tps', 0.72, 0.63, 1.38, -0.01, -0.13, 0.16, 0.22, 4.0, -0.36, -0.12, 0.11, 0.15, 5.9, -0.35, -0.12, '1', 1.0, 0.38, 2.0, -0.24, 0.62, 1.46, -0.09, 'O', 1.0, 2, 1, '1'),
#  (982, '21-10-2018', 'Finlande - Division 1', '13:30', 'Vaasa PS', 'Rovaniemi PS', 0.07, 0.26, 3.35, -0.77, -0.13, 0.29, 0.31, 2.85, -0.17, -0.12, 0.63, 0.44, 2.0, 0.26, -0.12, '2', 1.0, 0.62, 1.42, -0.12, 0.38, 2.1, -0.2, 'U', 0.0, 1, 2, '2'),
#  (983, '21-10-2018', 'Finlande - Division 1', '13:35', 'FC Inter', 'Honka', 0.12, 0.19, 4.5, -0.46, -0.15, 0.44, 0.26, 3.35, 0.47, -0.13, 0.44, 0.55, 1.6, -0.3, -0.12, 'N2', 1.0, 0.73, 1.7, 0.24, 0.27, 1.7, -0.54, 'U', 1.0, 0, 2, '2'),
#  (984, '21-10-2018', 'Finlande - Division 1', '13:35', 'Ps Kemi', 'Ifk Mariehamn', 0.29, 0.16, 5.6, 0.62, -0.1, 0.26, 0.22, 4.0, 0.04, -0.12, 0.45, 0.62, 1.41, -0.37, -0.13, None, None, 0.7, 1.92, 0.34, 0.3, 1.5, -0.55, 'U', 1.0, 2, 0, '1'),
#  (985, '21-10-2018', 'Grèce - Super League', '17:15', 'Levadiakos', 'Xanthi FC', 0.32, 0.39, 2.25, -0.28, -0.12, 0.37, 0.33, 2.65, -0.02, -0.13, 0.31, 0.27, 3.25, 0.01, -0.12, '1N', 0.0, 0.8, 1.33, 0.06, 0.21, 2.65, -0.44, 'U', 0.0, 1, 2, '2'),
#  (986, '21-10-2018', 'Grèce - Super League', '18:05', 'Aris Thessalonikis', 'Paok', 0.36, 0.28, 3.1, 0.12, -0.13, 0.19, 0.34, 2.6, -0.51, -0.12, 0.45, 0.38, 2.3, 0.03, -0.13, None, None, 0.74, 1.36, 0.01, 0.26, 2.35, -0.39, 'U', 0.0, 1, 2, '2'),
#  (987, '21-10-2018', 'Grèce - Super League', '19:30', 'OFI Crète', 'Olympiakos Piraeus', 0.23, 0.12, 7.25, 0.67, -0.13, 0.3, 0.22, 4.0, 0.2, -0.12, 0.47, 0.65, 1.36, -0.36, -0.12, None, None, 0.69, 1.8, 0.24, 0.32, 1.7, -0.46, 'U', 1.0, 1, 0, '1'),
#  (988, '21-10-2018', 'Italie - Serie B', '15:00', 'Salernitana', 'Perugia', 0.41, 0.43, 2.03, -0.17, -0.13, 0.41, 0.32, 2.75, 0.13, -0.12, 0.19, 0.26, 3.4, -0.35, -0.12, '1N', 1.0, 0.72, 1.42, 0.02, 0.28, 2.1, -0.41, 'U', 0.0, 2, 1, '1'),
#  (989, '21-10-2018', 'Italie - Serie B', '15:00', 'Venezia', 'Verona', 0.32, 0.36, 2.42, -0.23, -0.13, 0.31, 0.32, 2.77, -0.14, -0.11, 0.37, 0.32, 2.7, 0.0, -0.14, None, None, 0.54, 1.5, -0.19, 0.46, 1.92, -0.12, None, None, 1, 1, 'N'),
#  (990, '21-10-2018', 'Italie - Serie B', '21:00', 'Lecce', 'Palermo', 0.31, 0.35, 2.53, -0.22, -0.11, 0.39, 0.32, 2.75, 0.07, -0.12, 0.29, 0.34, 2.6, -0.25, -0.12, 'N', 0.0, 0.36, 1.44, -0.48, 0.64, 2.05, 0.31, 'O', 1.0, 1, 2, '2'),
#  (991, '21-10-2018', 'Japon - J1 League - Première Division', '09:00', None, 'aren Nagasaki ', 0.21, 0.37, 2.3, -0.52, -0.15, 0.38, 0.28, 3.07, 0.17, -0.14, 0.41, 0.34, 2.5, 0.02, -0.15, None, None, 0.62, 1.66, 0.03, 0.38, 1.73, -0.34, 'U', 1.0, 0, 0, 'N'),
#  (992, '21-10-2018', 'Lituanie - Lyga - Division 1', '12:00', 'Fk Zalgiris Vilnius', 'Fk Trakai', 0.34, 0.65, 1.36, -0.54, -0.12, 0.27, 0.21, 4.2, 0.13, -0.12, 0.39, 0.14, 6.5, 1.54, -0.09, None, None, 0.48, 1.7, -0.18, 0.52, 1.66, -0.14, None, None, 2, 2, 'N'),
#  (993, '21-10-2018', 'Lituanie - Lyga - Division 1', '12:00', 'Lietava Jonava', 'Suduva Marijampole', 0.05, 0.07, 13.0, -0.35, -0.09, 0.06, 0.15, 6.0, -0.64, -0.1, 0.89, 0.77, 1.2, 0.07, -0.08, '2', 1.0, 0.61, 2.6, 0.59, 0.39, 1.26, -0.51, 'U', 0.0, 1, 2, '2'),
#  (994, '21-10-2018', 'Luxembourg - Division 1', '16:00', 'FC Differdange 03', 'Victoria Rosport', 0.4, 0.62, 1.42, -0.43, -0.12, 0.28, 0.2, 4.4, 0.23, -0.12, 0.32, 0.18, 4.9, 0.57, -0.12, None, None, 0.49, 2.65, 0.3, 0.51, 1.24, -0.37, None, None, 3, 0, '1'),
#  (995, '21-10-2018', 'Luxembourg - Division 1', '16:00', 'Fola Esch', 'Etzella Ettelbruck', 0.44, 0.52, 1.67, -0.27, -0.13, 0.24, 0.23, 3.8, -0.09, -0.13, 0.33, 0.25, 3.5, 0.16, -0.12, None, None, 0.47, 2.5, 0.17, 0.54, 1.28, -0.31, None, None, 6, 0, '1'),
#  (996, '21-10-2018', 'Luxembourg - Division 1', '16:00', 'Rm Hamm Benfica', 'Us Hostert', 0.27, 0.41, 2.12, -0.43, -0.13, 0.35, 0.24, 3.55, 0.24, -0.15, 0.37, 0.35, 2.45, -0.09, -0.14, 'N2', 1.0, 0.61, 2.3, 0.4, 0.39, 1.33, -0.48, 'U', 0.0, 1, 2, '2'),
#  (997, '21-10-2018', 'Luxembourg - Division 1', '16:00', 'Una Strassen', 'Racing FC Union Luxembourg', 0.13, 0.51, 1.77, -0.77, -0.1, 0.17, 0.24, 3.7, -0.37, -0.11, 0.71, 0.25, 3.67, 1.61, -0.08, '2', 1.0, 0.68, 3.05, 1.07, 0.32, 1.17, -0.63, 'U', 0.0, 1, 2, '2'),
#  (998, '21-10-2018', 'Luxembourg - Division 1', '16:00', 'Union Titus Petange', 'AS Jeunesse Esch', 0.36, 0.31, 2.78, 0.0, -0.14, 0.19, 0.25, 3.45, -0.34, -0.14, 0.45, 0.44, 1.97, -0.11, -0.13, None, None, 0.38, 2.2, -0.16, 0.62, 1.37, -0.15, 'O', 1.0, 3, 2, '1'),
#  (999, '21-10-2018', 'Luxembourg - Division 1', '16:00', 'Us Mondor', 'es', 0.48, 0.49, 1.78, -0.15, -0.13, 0.24, 0.23, 3.8, -0.09, -0.13, 0.28, 0.28, 3.1, -0.13, -0.13, None, None, 0.63, 2.3, 0.45, 0.37, 1.33, -0.51, 'U', 0.0, 4, 3, '1'),
#  ...]
